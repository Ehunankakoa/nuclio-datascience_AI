# %% [markdown]
# # Entregable 2: Windows Defender detector

# %% [markdown]
# ## 1. Importación de librerías, primera visualización de dataframe, comprobación de duplicados y target = "HasDetections"

# %%
# IMPORTAMOS LIBRERÍAS

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, MinMaxScaler

# %%
#csv_path = r"D:\Documentos\Nuclio\Entregable_2\sample_mmp.csv"
#csv_path = r"C:\Users\jonmi\Documents\Nuclio\nuclio-datascience_AI\Entregable_2\sample_mmp.csv"
csv_path = r"C:\Users\JGarcia94\OneDrive - Lear Corporation\Documents\GITHub_Repository\nuclio-datascience_AI\Entregable_2\sample_mmp.csv"
df = pd.read_csv(csv_path, dtype={"PuaMode": 'category', "Census_ProcessorClass": "category"})

# %%
df.shape
# Out:
# (500000, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 84 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   Unnamed: 0                                         500000 non-null  int64
#  1   MachineIdentifier                                  500000 non-null  object
#  2   ProductName                                        500000 non-null  object
#  3   EngineVersion                                      500000 non-null  object
#  4   AppVersion                                         500000 non-null  object
#  5   AvSigVersion                                       500000 non-null  object
#  6   IsBeta                                             500000 non-null  int64
#  7   RtpStateBitfield                                   498168 non-null  float64
#  8   IsSxsPassiveMode                                   500000 non-null  int64
#  9   DefaultBrowsersIdentifier                          24061 non-null   float64
#  10  AVProductStatesIdentifier                          498062 non-null  float64
#  11  AVProductsInstalled                                498062 non-null  float64
#  12  AVProductsEnabled                                  498062 non-null  float64
#  13  HasTpm                                             500000 non-null  int64
#  14  CountryIdentifier                                  500000 non-null  int64
#  15  CityIdentifier                                     481760 non-null  float64
#  16  OrganizationIdentifier                             345437 non-null  float64
#  17  GeoNameIdentifier                                  499984 non-null  float64
#  18  LocaleEnglishNameIdentifier                        500000 non-null  int64
#  19  Platform                                           500000 non-null  object
#  20  Processor                                          500000 non-null  object
#  21  OsVer                                              500000 non-null  object
#  22  OsBuild                                            500000 non-null  int64
#  23  OsSuite                                            500000 non-null  int64
#  24  OsPlatformSubRelease                               500000 non-null  object
#  25  OsBuildLab                                         499999 non-null  object
#  26  SkuEdition                                         500000 non-null  object
#  27  IsProtected                                        498074 non-null  float64
#  28  AutoSampleOptIn                                    500000 non-null  int64
#  29  PuaMode                                            126 non-null     category
#  30  SMode                                              470152 non-null  float64
#  31  IeVerIdentifier                                    496791 non-null  float64
#  32  SmartScreen                                        321404 non-null  object
#  33  Firewall                                           494838 non-null  float64
#  34  UacLuaenable                                       499377 non-null  float64
#  35  Census_MDC2FormFactor                              500000 non-null  object
#  36  Census_DeviceFamily                                500000 non-null  object
#  37  Census_OEMNameIdentifier                           494619 non-null  float64
#  38  Census_OEMModelIdentifier                          494236 non-null  float64
#  39  Census_ProcessorCoreCount                          497653 non-null  float64
#  40  Census_ProcessorManufacturerIdentifier             497653 non-null  float64
#  41  Census_ProcessorModelIdentifier                    497651 non-null  float64
#  42  Census_ProcessorClass                              2082 non-null    category
#  43  Census_PrimaryDiskTotalCapacity                    497024 non-null  float64
#  44  Census_PrimaryDiskTypeName                         499291 non-null  object
#  45  Census_SystemVolumeTotalCapacity                   497024 non-null  float64
#  46  Census_HasOpticalDiskDrive                         500000 non-null  int64
#  47  Census_TotalPhysicalRAM                            495444 non-null  float64
#  48  Census_ChassisTypeName                             499963 non-null  object
#  49  Census_InternalPrimaryDiagonalDisplaySizeInInches  497346 non-null  float64
#  50  Census_InternalPrimaryDisplayResolutionHorizontal  497350 non-null  float64
#  51  Census_InternalPrimaryDisplayResolutionVertical    497350 non-null  float64
#  52  Census_PowerPlatformRoleName                       499998 non-null  object
#  53  Census_InternalBatteryType                         144397 non-null  object
#  54  Census_InternalBatteryNumberOfCharges              484962 non-null  float64
#  55  Census_OSVersion                                   500000 non-null  object
#  56  Census_OSArchitecture                              500000 non-null  object
#  57  Census_OSBranch                                    500000 non-null  object
#  58  Census_OSBuildNumber                               500000 non-null  int64
#  59  Census_OSBuildRevision                             500000 non-null  int64
#  60  Census_OSEdition                                   500000 non-null  object
#  61  Census_OSSkuName                                   500000 non-null  object
#  62  Census_OSInstallTypeName                           500000 non-null  object
#  63  Census_OSInstallLanguageIdentifier                 496668 non-null  float64
#  64  Census_OSUILocaleIdentifier                        500000 non-null  int64
#  65  Census_OSWUAutoUpdateOptionsName                   500000 non-null  object
#  66  Census_IsPortableOperatingSystem                   500000 non-null  int64
#  67  Census_GenuineStateName                            500000 non-null  object
#  68  Census_ActivationChannel                           500000 non-null  object
#  69  Census_IsFlightingInternal                         84775 non-null   float64
#  70  Census_IsFlightsDisabled                           491067 non-null  float64
#  71  Census_FlightRing                                  500000 non-null  object
#  72  Census_ThresholdOptIn                              181896 non-null  float64
#  73  Census_FirmwareManufacturerIdentifier              489651 non-null  float64
#  74  Census_FirmwareVersionIdentifier                   490939 non-null  float64
#  75  Census_IsSecureBootEnabled                         500000 non-null  int64
#  76  Census_IsWIMBootEnabled                            182334 non-null  float64
#  77  Census_IsVirtualDevice                             499099 non-null  float64
#  78  Census_IsTouchEnabled                              500000 non-null  int64
#  79  Census_IsPenCapable                                500000 non-null  int64
#  80  Census_IsAlwaysOnAlwaysConnectedCapable            495960 non-null  float64
#  81  Wdft_IsGamer                                       483050 non-null  float64
#  82  Wdft_RegionIdentifier                              483050 non-null  float64
#  83  HasDetections                                      500000 non-null  int64
# dtypes: category(2), float64(36), int64(18), object(28)
# memory usage: 313.8+ MB

# %%
df.head().T
# Out:
#                                                                                           0  \
# Unnamed: 0                                                                          8427007
# MachineIdentifier                                          f1cd864e97bae82bdf96523e1a539121
# ProductName                                                                    win8defender
# EngineVersion                                                                   1.1.15100.1
# AppVersion                                                                  4.18.1807.18075
# AvSigVersion                                                                   1.273.1234.0
# IsBeta                                                                                    0
# RtpStateBitfield                                                                        7.0
# IsSxsPassiveMode                                                                          0
# DefaultBrowsersIdentifier                                                               NaN
# AVProductStatesIdentifier                                                           53447.0
# AVProductsInstalled                                                                     1.0
# AVProductsEnabled                                                                       1.0
# HasTpm                                                                                    1
# CountryIdentifier                                                                         8
# CityIdentifier                                                                      85219.0
# OrganizationIdentifier                                                                  NaN
# GeoNameIdentifier                                                                     205.0
# LocaleEnglishNameIdentifier                                                             172
# Platform                                                                          windows10
# Processor                                                                               x64
# OsVer                                                                              10.0.0.0
# OsBuild                                                                               17134
# OsSuite                                                                                 256
# OsPlatformSubRelease                                                                    rs4
# OsBuildLab                                         17134.1.amd64fre.rs4_release.180410-1804
# SkuEdition                                                                              Pro
# IsProtected                                                                             1.0
# AutoSampleOptIn                                                                           0
# PuaMode                                                                                 NaN
# SMode                                                                                   0.0
# IeVerIdentifier                                                                       137.0
# SmartScreen                                                                    RequireAdmin
# Firewall                                                                                1.0
# UacLuaenable                                                                            1.0
# Census_MDC2FormFactor                                                               Desktop
# Census_DeviceFamily                                                         Windows.Desktop
# Census_OEMNameIdentifier                                                             1443.0
# Census_OEMModelIdentifier                                                          275891.0
# Census_ProcessorCoreCount                                                               4.0
# Census_ProcessorManufacturerIdentifier                                                  5.0
# Census_ProcessorModelIdentifier                                                      2273.0
# Census_ProcessorClass                                                                   NaN
# Census_PrimaryDiskTotalCapacity                                                    953869.0
# Census_PrimaryDiskTypeName                                                              HDD
# Census_SystemVolumeTotalCapacity                                                   952838.0
# Census_HasOpticalDiskDrive                                                                0
# Census_TotalPhysicalRAM                                                              8192.0
# Census_ChassisTypeName                                                             AllinOne
# Census_InternalPrimaryDiagonalDisplaySizeInInches                                      23.0
# Census_InternalPrimaryDisplayResolutionHorizontal                                    1920.0
# Census_InternalPrimaryDisplayResolutionVertical                                      1080.0
# Census_PowerPlatformRoleName                                                        Desktop
# Census_InternalBatteryType                                                              NaN
# Census_InternalBatteryNumberOfCharges                                          4294967295.0
# Census_OSVersion                                                             10.0.17134.165
# Census_OSArchitecture                                                                 amd64
# Census_OSBranch                                                                 rs4_release
# Census_OSBuildNumber                                                                  17134
# Census_OSBuildRevision                                                                  165
# Census_OSEdition                                                               Professional
# Census_OSSkuName                                                               PROFESSIONAL
# Census_OSInstallTypeName                                                         UUPUpgrade
# Census_OSInstallLanguageIdentifier                                                     27.0
# Census_OSUILocaleIdentifier                                                             120
# Census_OSWUAutoUpdateOptionsName                                                   FullAuto
# Census_IsPortableOperatingSystem                                                          0
# Census_GenuineStateName                                                          IS_GENUINE
# Census_ActivationChannel                                                             OEM:DM
# Census_IsFlightingInternal                                                              NaN
# Census_IsFlightsDisabled                                                                0.0
# Census_FlightRing                                                                    Retail
# Census_ThresholdOptIn                                                                   NaN
# Census_FirmwareManufacturerIdentifier                                                 355.0
# Census_FirmwareVersionIdentifier                                                    19951.0
# Census_IsSecureBootEnabled                                                                0
# Census_IsWIMBootEnabled                                                                 NaN
# Census_IsVirtualDevice                                                                  0.0
# Census_IsTouchEnabled                                                                     0
# Census_IsPenCapable                                                                       0
# Census_IsAlwaysOnAlwaysConnectedCapable                                                 0.0
# Wdft_IsGamer                                                                            0.0
# Wdft_RegionIdentifier                                                                  11.0
# HasDetections                                                                             1
#
#                                                                                           1  \
# Unnamed: 0                                                                          8829090
# MachineIdentifier                                          fd5ba6f5b75325ec0423a6c67cc75942
# ProductName                                                                    win8defender
# EngineVersion                                                                   1.1.15100.1
# AppVersion                                                                  4.18.1807.18075
# AvSigVersion                                                                   1.273.1282.0
# IsBeta                                                                                    0
# RtpStateBitfield                                                                        7.0
# IsSxsPassiveMode                                                                          0
# DefaultBrowsersIdentifier                                                               NaN
# AVProductStatesIdentifier                                                           53447.0
# AVProductsInstalled                                                                     1.0
# AVProductsEnabled                                                                       1.0
# HasTpm                                                                                    1
# CountryIdentifier                                                                       129
# CityIdentifier                                                                      54198.0
# OrganizationIdentifier                                                                  NaN
# GeoNameIdentifier                                                                     126.0
# LocaleEnglishNameIdentifier                                                             124
# Platform                                                                          windows10
# Processor                                                                               x64
# OsVer                                                                              10.0.0.0
# OsBuild                                                                               17134
# OsSuite                                                                                 256
# OsPlatformSubRelease                                                                    rs4
# OsBuildLab                                         17134.1.amd64fre.rs4_release.180410-1804
# SkuEdition                                                                              Pro
# IsProtected                                                                             1.0
# AutoSampleOptIn                                                                           0
# PuaMode                                                                                 NaN
# SMode                                                                                   0.0
# IeVerIdentifier                                                                       137.0
# SmartScreen                                                                    RequireAdmin
# Firewall                                                                                1.0
# UacLuaenable                                                                            1.0
# Census_MDC2FormFactor                                                              Notebook
# Census_DeviceFamily                                                         Windows.Desktop
# Census_OEMNameIdentifier                                                             2102.0
# Census_OEMModelIdentifier                                                          248850.0
# Census_ProcessorCoreCount                                                               4.0
# Census_ProcessorManufacturerIdentifier                                                  5.0
# Census_ProcessorModelIdentifier                                                      2660.0
# Census_ProcessorClass                                                                   NaN
# Census_PrimaryDiskTotalCapacity                                                    476940.0
# Census_PrimaryDiskTypeName                                                              HDD
# Census_SystemVolumeTotalCapacity                                                   457600.0
# Census_HasOpticalDiskDrive                                                                0
# Census_TotalPhysicalRAM                                                              8192.0
# Census_ChassisTypeName                                                             Notebook
# Census_InternalPrimaryDiagonalDisplaySizeInInches                                      13.2
# Census_InternalPrimaryDisplayResolutionHorizontal                                    1280.0
# Census_InternalPrimaryDisplayResolutionVertical                                       720.0
# Census_PowerPlatformRoleName                                                         Mobile
# Census_InternalBatteryType                                                             lion
# Census_InternalBatteryNumberOfCharges                                                   0.0
# Census_OSVersion                                                             10.0.17134.165
# Census_OSArchitecture                                                                 amd64
# Census_OSBranch                                                                 rs4_release
# Census_OSBuildNumber                                                                  17134
# Census_OSBuildRevision                                                                  165
# Census_OSEdition                                                               Professional
# Census_OSSkuName                                                               PROFESSIONAL
# Census_OSInstallTypeName                                                         UUPUpgrade
# Census_OSInstallLanguageIdentifier                                                     18.0
# Census_OSUILocaleIdentifier                                                              72
# Census_OSWUAutoUpdateOptionsName                                                   FullAuto
# Census_IsPortableOperatingSystem                                                          0
# Census_GenuineStateName                                                          IS_GENUINE
# Census_ActivationChannel                                                             OEM:DM
# Census_IsFlightingInternal                                                              NaN
# Census_IsFlightsDisabled                                                                0.0
# Census_FlightRing                                                                    Retail
# Census_ThresholdOptIn                                                                   0.0
# Census_FirmwareManufacturerIdentifier                                                 486.0
# Census_FirmwareVersionIdentifier                                                    48753.0
# Census_IsSecureBootEnabled                                                                0
# Census_IsWIMBootEnabled                                                                 0.0
# Census_IsVirtualDevice                                                                  0.0
# Census_IsTouchEnabled                                                                     0
# Census_IsPenCapable                                                                       0
# Census_IsAlwaysOnAlwaysConnectedCapable                                                 0.0
# Wdft_IsGamer                                                                            1.0
# Wdft_RegionIdentifier                                                                   3.0
# HasDetections                                                                             0
#
#                                                                                                  2  \
# Unnamed: 0                                                                                 2731904
# MachineIdentifier                                                 4e628391e7cc7c482fb3286f486dbd25
# ProductName                                                                           win8defender
# EngineVersion                                                                          1.1.15100.1
# AppVersion                                                                          4.9.10586.1106
# AvSigVersion                                                                           1.273.781.0
# IsBeta                                                                                           0
# RtpStateBitfield                                                                               7.0
# IsSxsPassiveMode                                                                                 0
# DefaultBrowsersIdentifier                                                                      NaN
# AVProductStatesIdentifier                                                                  46781.0
# AVProductsInstalled                                                                            2.0
# AVProductsEnabled                                                                              1.0
# HasTpm                                                                                           1
# CountryIdentifier                                                                              149
# CityIdentifier                                                                            122689.0
# OrganizationIdentifier                                                                        27.0
# GeoNameIdentifier                                                                            181.0
# LocaleEnglishNameIdentifier                                                                     56
# Platform                                                                                 windows10
# Processor                                                                                      x64
# OsVer                                                                                     10.0.0.0
# OsBuild                                                                                      10586
# OsSuite                                                                                        768
# OsPlatformSubRelease                                                                           th2
# OsBuildLab                                         10586.1176.amd64fre.th2_release_sec.170913-1848
# SkuEdition                                                                                    Home
# IsProtected                                                                                    1.0
# AutoSampleOptIn                                                                                  0
# PuaMode                                                                                        NaN
# SMode                                                                                          0.0
# IeVerIdentifier                                                                               74.0
# SmartScreen                                                                           RequireAdmin
# Firewall                                                                                       1.0
# UacLuaenable                                                                                   1.0
# Census_MDC2FormFactor                                                                  Convertible
# Census_DeviceFamily                                                                Windows.Desktop
# Census_OEMNameIdentifier                                                                    2206.0
# Census_OEMModelIdentifier                                                                 238234.0
# Census_ProcessorCoreCount                                                                      4.0
# Census_ProcessorManufacturerIdentifier                                                         5.0
# Census_ProcessorModelIdentifier                                                             2998.0
# Census_ProcessorClass                                                                          NaN
# Census_PrimaryDiskTotalCapacity                                                           244198.0
# Census_PrimaryDiskTypeName                                                                     SSD
# Census_SystemVolumeTotalCapacity                                                          221251.0
# Census_HasOpticalDiskDrive                                                                       0
# Census_TotalPhysicalRAM                                                                     8192.0
# Census_ChassisTypeName                                                                    Notebook
# Census_InternalPrimaryDiagonalDisplaySizeInInches                                             15.5
# Census_InternalPrimaryDisplayResolutionHorizontal                                           1920.0
# Census_InternalPrimaryDisplayResolutionVertical                                             1080.0
# Census_PowerPlatformRoleName                                                                Mobile
# Census_InternalBatteryType                                                                    lion
# Census_InternalBatteryNumberOfCharges                                                          0.0
# Census_OSVersion                                                                   10.0.10586.1176
# Census_OSArchitecture                                                                        amd64
# Census_OSBranch                                                                    th2_release_sec
# Census_OSBuildNumber                                                                         10586
# Census_OSBuildRevision                                                                        1176
# Census_OSEdition                                                                              Core
# Census_OSSkuName                                                                              CORE
# Census_OSInstallTypeName                                                                    Update
# Census_OSInstallLanguageIdentifier                                                            24.0
# Census_OSUILocaleIdentifier                                                                    109
# Census_OSWUAutoUpdateOptionsName                                                            Notify
# Census_IsPortableOperatingSystem                                                                 0
# Census_GenuineStateName                                                                 IS_GENUINE
# Census_ActivationChannel                                                                    Retail
# Census_IsFlightingInternal                                                                     NaN
# Census_IsFlightsDisabled                                                                       0.0
# Census_FlightRing                                                                           Retail
# Census_ThresholdOptIn                                                                          0.0
# Census_FirmwareManufacturerIdentifier                                                        554.0
# Census_FirmwareVersionIdentifier                                                           33111.0
# Census_IsSecureBootEnabled                                                                       1
# Census_IsWIMBootEnabled                                                                        0.0
# Census_IsVirtualDevice                                                                         0.0
# Census_IsTouchEnabled                                                                            1
# Census_IsPenCapable                                                                              1
# Census_IsAlwaysOnAlwaysConnectedCapable                                                        0.0
# Wdft_IsGamer                                                                                   0.0
# Wdft_RegionIdentifier                                                                         15.0
# HasDetections                                                                                    0
#
#                                                                                           3  \
# Unnamed: 0                                                                          1359513
# MachineIdentifier                                          270a2e9d028144a4df12a9e3da79fba5
# ProductName                                                                    win8defender
# EngineVersion                                                                   1.1.15200.1
# AppVersion                                                                  4.18.1807.18075
# AvSigVersion                                                                   1.275.1639.0
# IsBeta                                                                                    0
# RtpStateBitfield                                                                        7.0
# IsSxsPassiveMode                                                                          0
# DefaultBrowsersIdentifier                                                               NaN
# AVProductStatesIdentifier                                                           53447.0
# AVProductsInstalled                                                                     1.0
# AVProductsEnabled                                                                       1.0
# HasTpm                                                                                    1
# CountryIdentifier                                                                       164
# CityIdentifier                                                                     114587.0
# OrganizationIdentifier                                                                 27.0
# GeoNameIdentifier                                                                     205.0
# LocaleEnglishNameIdentifier                                                             172
# Platform                                                                          windows10
# Processor                                                                               x64
# OsVer                                                                              10.0.0.0
# OsBuild                                                                               17134
# OsSuite                                                                                 768
# OsPlatformSubRelease                                                                    rs4
# OsBuildLab                                         17134.1.amd64fre.rs4_release.180410-1804
# SkuEdition                                                                             Home
# IsProtected                                                                             1.0
# AutoSampleOptIn                                                                           0
# PuaMode                                                                                 NaN
# SMode                                                                                   0.0
# IeVerIdentifier                                                                       137.0
# SmartScreen                                                                             NaN
# Firewall                                                                                1.0
# UacLuaenable                                                                            1.0
# Census_MDC2FormFactor                                                              Notebook
# Census_DeviceFamily                                                         Windows.Desktop
# Census_OEMNameIdentifier                                                              525.0
# Census_OEMModelIdentifier                                                          265410.0
# Census_ProcessorCoreCount                                                               8.0
# Census_ProcessorManufacturerIdentifier                                                  5.0
# Census_ProcessorModelIdentifier                                                      2880.0
# Census_ProcessorClass                                                                   NaN
# Census_PrimaryDiskTotalCapacity                                                    228936.0
# Census_PrimaryDiskTypeName                                                              SSD
# Census_SystemVolumeTotalCapacity                                                   228321.0
# Census_HasOpticalDiskDrive                                                                0
# Census_TotalPhysicalRAM                                                              8192.0
# Census_ChassisTypeName                                                             Notebook
# Census_InternalPrimaryDiagonalDisplaySizeInInches                                      15.5
# Census_InternalPrimaryDisplayResolutionHorizontal                                    1920.0
# Census_InternalPrimaryDisplayResolutionVertical                                      1080.0
# Census_PowerPlatformRoleName                                                         Mobile
# Census_InternalBatteryType                                                              NaN
# Census_InternalBatteryNumberOfCharges                                                 577.0
# Census_OSVersion                                                             10.0.17134.286
# Census_OSArchitecture                                                                 amd64
# Census_OSBranch                                                                 rs4_release
# Census_OSBuildNumber                                                                  17134
# Census_OSBuildRevision                                                                  286
# Census_OSEdition                                                                       Core
# Census_OSSkuName                                                                       CORE
# Census_OSInstallTypeName                                                           IBSClean
# Census_OSInstallLanguageIdentifier                                                     27.0
# Census_OSUILocaleIdentifier                                                             120
# Census_OSWUAutoUpdateOptionsName                                                   FullAuto
# Census_IsPortableOperatingSystem                                                          0
# Census_GenuineStateName                                                          IS_GENUINE
# Census_ActivationChannel                                                             Retail
# Census_IsFlightingInternal                                                              NaN
# Census_IsFlightsDisabled                                                                0.0
# Census_FlightRing                                                                    Retail
# Census_ThresholdOptIn                                                                   NaN
# Census_FirmwareManufacturerIdentifier                                                 142.0
# Census_FirmwareVersionIdentifier                                                    48473.0
# Census_IsSecureBootEnabled                                                                1
# Census_IsWIMBootEnabled                                                                 NaN
# Census_IsVirtualDevice                                                                  0.0
# Census_IsTouchEnabled                                                                     0
# Census_IsPenCapable                                                                       0
# Census_IsAlwaysOnAlwaysConnectedCapable                                                 0.0
# Wdft_IsGamer                                                                            0.0
# Wdft_RegionIdentifier                                                                  15.0
# HasDetections                                                                             1
#
#                                                                                           4
# Unnamed: 0                                                                           236059
# MachineIdentifier                                          06ca8fa8d32c2abdc5b3577d676b3269
# ProductName                                                                    win8defender
# EngineVersion                                                                   1.1.15200.1
# AppVersion                                                                  4.18.1807.18075
# AvSigVersion                                                                    1.275.511.0
# IsBeta                                                                                    0
# RtpStateBitfield                                                                        7.0
# IsSxsPassiveMode                                                                          0
# DefaultBrowsersIdentifier                                                               NaN
# AVProductStatesIdentifier                                                           47238.0
# AVProductsInstalled                                                                     2.0
# AVProductsEnabled                                                                       1.0
# HasTpm                                                                                    1
# CountryIdentifier                                                                       207
# CityIdentifier                                                                      72421.0
# OrganizationIdentifier                                                                 27.0
# GeoNameIdentifier                                                                     277.0
# LocaleEnglishNameIdentifier                                                              75
# Platform                                                                          windows10
# Processor                                                                               x64
# OsVer                                                                              10.0.0.0
# OsBuild                                                                               17134
# OsSuite                                                                                 256
# OsPlatformSubRelease                                                                    rs4
# OsBuildLab                                         17134.1.amd64fre.rs4_release.180410-1804
# SkuEdition                                                                              Pro
# IsProtected                                                                             1.0
# AutoSampleOptIn                                                                           0
# PuaMode                                                                                 NaN
# SMode                                                                                   0.0
# IeVerIdentifier                                                                       137.0
# SmartScreen                                                                    RequireAdmin
# Firewall                                                                                1.0
# UacLuaenable                                                                            1.0
# Census_MDC2FormFactor                                                              Notebook
# Census_DeviceFamily                                                         Windows.Desktop
# Census_OEMNameIdentifier                                                             1443.0
# Census_OEMModelIdentifier                                                          256478.0
# Census_ProcessorCoreCount                                                               4.0
# Census_ProcessorManufacturerIdentifier                                                  1.0
# Census_ProcessorModelIdentifier                                                       198.0
# Census_ProcessorClass                                                                   NaN
# Census_PrimaryDiskTotalCapacity                                                    476940.0
# Census_PrimaryDiskTypeName                                                              HDD
# Census_SystemVolumeTotalCapacity                                                   464374.0
# Census_HasOpticalDiskDrive                                                                0
# Census_TotalPhysicalRAM                                                              4096.0
# Census_ChassisTypeName                                                             Portable
# Census_InternalPrimaryDiagonalDisplaySizeInInches                                      15.5
# Census_InternalPrimaryDisplayResolutionHorizontal                                    1366.0
# Census_InternalPrimaryDisplayResolutionVertical                                       768.0
# Census_PowerPlatformRoleName                                                         Mobile
# Census_InternalBatteryType                                                              NaN
# Census_InternalBatteryNumberOfCharges                                                   0.0
# Census_OSVersion                                                             10.0.17134.228
# Census_OSArchitecture                                                                 amd64
# Census_OSBranch                                                                 rs4_release
# Census_OSBuildNumber                                                                  17134
# Census_OSBuildRevision                                                                  228
# Census_OSEdition                                                               Professional
# Census_OSSkuName                                                               PROFESSIONAL
# Census_OSInstallTypeName                                                             Update
# Census_OSInstallLanguageIdentifier                                                      8.0
# Census_OSUILocaleIdentifier                                                              31
# Census_OSWUAutoUpdateOptionsName                                                   FullAuto
# Census_IsPortableOperatingSystem                                                          0
# Census_GenuineStateName                                                          IS_GENUINE
# Census_ActivationChannel                                                             OEM:DM
# Census_IsFlightingInternal                                                              NaN
# Census_IsFlightsDisabled                                                                0.0
# Census_FlightRing                                                                    Retail
# Census_ThresholdOptIn                                                                   NaN
# Census_FirmwareManufacturerIdentifier                                                 355.0
# Census_FirmwareVersionIdentifier                                                     4343.0
# Census_IsSecureBootEnabled                                                                1
# Census_IsWIMBootEnabled                                                                 NaN
# Census_IsVirtualDevice                                                                  0.0
# Census_IsTouchEnabled                                                                     1
# Census_IsPenCapable                                                                       0
# Census_IsAlwaysOnAlwaysConnectedCapable                                                 0.0
# Wdft_IsGamer                                                                            1.0
# Wdft_RegionIdentifier                                                                  13.0
# HasDetections                                                                             1

# %%
pd.set_option('display.max_rows', 100)

# %%
numeric_describe = df.describe(include='number').T
numeric_describe
# Out:
#                                                       count          mean  \
# Unnamed: 0                                         500000.0  4.458888e+06
# IsBeta                                             500000.0  2.000000e-06
# RtpStateBitfield                                   498168.0  6.846207e+00
# IsSxsPassiveMode                                   500000.0  1.724200e-02
# DefaultBrowsersIdentifier                           24061.0  1.652825e+03
# AVProductStatesIdentifier                          498062.0  4.785091e+04
# AVProductsInstalled                                498062.0  1.326763e+00
# AVProductsEnabled                                  498062.0  1.020714e+00
# HasTpm                                             500000.0  9.878160e-01
# CountryIdentifier                                  500000.0  1.080375e+02
# CityIdentifier                                     481760.0  8.127165e+04
# OrganizationIdentifier                             345437.0  2.486994e+01
# GeoNameIdentifier                                  499984.0  1.697304e+02
# LocaleEnglishNameIdentifier                        500000.0  1.226110e+02
# OsBuild                                            500000.0  1.572693e+04
# OsSuite                                            500000.0  5.747186e+02
# IsProtected                                        498074.0  9.457892e-01
# AutoSampleOptIn                                    500000.0  2.800000e-05
# SMode                                              470152.0  4.381562e-04
# IeVerIdentifier                                    496791.0  1.266626e+02
# Firewall                                           494838.0  9.782414e-01
# UacLuaenable                                       499377.0  1.372503e+01
# Census_OEMNameIdentifier                           494619.0  2.218646e+03
# Census_OEMModelIdentifier                          494236.0  2.391280e+05
# Census_ProcessorCoreCount                          497653.0  3.994074e+00
# Census_ProcessorManufacturerIdentifier             497653.0  4.529069e+00
# Census_ProcessorModelIdentifier                    497651.0  2.370987e+03
# Census_PrimaryDiskTotalCapacity                    497024.0  5.140433e+05
# Census_SystemVolumeTotalCapacity                   497024.0  3.780546e+05
# Census_HasOpticalDiskDrive                         500000.0  7.703400e-02
# Census_TotalPhysicalRAM                            495444.0  6.129232e+03
# Census_InternalPrimaryDiagonalDisplaySizeInInches  497346.0  1.668984e+01
# Census_InternalPrimaryDisplayResolutionHorizontal  497350.0  1.548304e+03
# Census_InternalPrimaryDisplayResolutionVertical    497350.0  8.982393e+02
# Census_InternalBatteryNumberOfCharges              484962.0  1.125600e+09
# Census_OSBuildNumber                               500000.0  1.584137e+04
# Census_OSBuildRevision                             500000.0  9.672248e+02
# Census_OSInstallLanguageIdentifier                 496668.0  1.460551e+01
# Census_OSUILocaleIdentifier                        500000.0  6.044631e+01
# Census_IsPortableOperatingSystem                   500000.0  5.220000e-04
# Census_IsFlightingInternal                          84775.0  2.359186e-05
# Census_IsFlightsDisabled                           491067.0  1.425467e-05
# Census_ThresholdOptIn                              181896.0  2.583894e-04
# Census_FirmwareManufacturerIdentifier              489651.0  4.026759e+02
# Census_FirmwareVersionIdentifier                   490939.0  3.303099e+04
# Census_IsSecureBootEnabled                         500000.0  4.854380e-01
# Census_IsWIMBootEnabled                            182334.0  0.000000e+00
# Census_IsVirtualDevice                             499099.0  7.066734e-03
# Census_IsTouchEnabled                              500000.0  1.254340e-01
# Census_IsPenCapable                                500000.0  3.774400e-02
# Census_IsAlwaysOnAlwaysConnectedCapable            495960.0  5.724454e-02
# Wdft_IsGamer                                       483050.0  2.840596e-01
# Wdft_RegionIdentifier                              483050.0  7.888577e+00
# HasDetections                                      500000.0  4.999060e-01
#
#                                                             std      min  \
# Unnamed: 0                                         2.575619e+06      2.0
# IsBeta                                             1.414214e-03      0.0
# RtpStateBitfield                                   1.023049e+00      0.0
# IsSxsPassiveMode                                   1.301720e-01      0.0
# DefaultBrowsersIdentifier                          1.004754e+03      1.0
# AVProductStatesIdentifier                          1.402309e+04      3.0
# AVProductsInstalled                                5.229999e-01      1.0
# AVProductsEnabled                                  1.666080e-01      0.0
# HasTpm                                             1.097068e-01      0.0
# CountryIdentifier                                  6.306854e+01      1.0
# CityIdentifier                                     4.898513e+04      7.0
# OrganizationIdentifier                             5.613712e+00      1.0
# GeoNameIdentifier                                  8.932517e+01      1.0
# LocaleEnglishNameIdentifier                        6.930317e+01      1.0
# OsBuild                                            2.188646e+03   7600.0
# OsSuite                                            2.482033e+02     16.0
# IsProtected                                        2.264335e-01      0.0
# AutoSampleOptIn                                    5.291434e-03      0.0
# SMode                                              2.092762e-02      0.0
# IeVerIdentifier                                    4.263489e+01      8.0
# Firewall                                           1.458946e-01      0.0
# UacLuaenable                                       8.995848e+03      0.0
# Census_OEMNameIdentifier                           1.315710e+03     54.0
# Census_OEMModelIdentifier                          7.204888e+04      1.0
# Census_ProcessorCoreCount                          2.071281e+00      1.0
# Census_ProcessorManufacturerIdentifier             1.289635e+00      1.0
# Census_ProcessorModelIdentifier                    8.421367e+02      3.0
# Census_PrimaryDiskTotalCapacity                    3.704468e+05  10240.0
# Census_SystemVolumeTotalCapacity                   3.384722e+05   9689.0
# Census_HasOpticalDiskDrive                         2.666457e-01      0.0
# Census_TotalPhysicalRAM                            4.964521e+03    512.0
# Census_InternalPrimaryDiagonalDisplaySizeInInches  5.932014e+00      4.9
# Census_InternalPrimaryDisplayResolutionHorizontal  3.685659e+02     -1.0
# Census_InternalPrimaryDisplayResolutionVertical    2.148625e+02     -1.0
# Census_InternalBatteryNumberOfCharges              1.888768e+09      0.0
# Census_OSBuildNumber                               1.959440e+03   9600.0
# Census_OSBuildRevision                             2.920628e+03      0.0
# Census_OSInstallLanguageIdentifier                 1.020095e+01      1.0
# Census_OSUILocaleIdentifier                        4.500042e+01      1.0
# Census_IsPortableOperatingSystem                   2.284138e-02      0.0
# Census_IsFlightingInternal                         4.857117e-03      0.0
# Census_IsFlightsDisabled                           3.775513e-03      0.0
# Census_ThresholdOptIn                              1.607246e-02      0.0
# Census_FirmwareManufacturerIdentifier              2.215271e+02     11.0
# Census_FirmwareVersionIdentifier                   2.122016e+04     10.0
# Census_IsSecureBootEnabled                         4.997884e-01      0.0
# Census_IsWIMBootEnabled                            0.000000e+00      0.0
# Census_IsVirtualDevice                             8.376640e-02      0.0
# Census_IsTouchEnabled                              3.312107e-01      0.0
# Census_IsPenCapable                                1.905767e-01      0.0
# Census_IsAlwaysOnAlwaysConnectedCapable            2.323095e-01      0.0
# Wdft_IsGamer                                       4.509658e-01      0.0
# Wdft_RegionIdentifier                              4.551764e+00      1.0
# HasDetections                                      5.000005e-01      0.0
#
#                                                           25%        50%  \
# Unnamed: 0                                         2227692.50  4461367.5
# IsBeta                                                   0.00        0.0
# RtpStateBitfield                                         7.00        7.0
# IsSxsPassiveMode                                         0.00        0.0
# DefaultBrowsersIdentifier                              788.00     1632.0
# AVProductStatesIdentifier                            49480.00    53447.0
# AVProductsInstalled                                      1.00        1.0
# AVProductsEnabled                                        1.00        1.0
# HasTpm                                                   1.00        1.0
# CountryIdentifier                                       51.00       97.0
# CityIdentifier                                       36825.00    82373.0
# OrganizationIdentifier                                  18.00       27.0
# GeoNameIdentifier                                       89.00      181.0
# LocaleEnglishNameIdentifier                             74.00       88.0
# OsBuild                                              15063.00    16299.0
# OsSuite                                                256.00      768.0
# IsProtected                                              1.00        1.0
# AutoSampleOptIn                                          0.00        0.0
# SMode                                                    0.00        0.0
# IeVerIdentifier                                        111.00      135.0
# Firewall                                                 1.00        1.0
# UacLuaenable                                             1.00        1.0
# Census_OEMNameIdentifier                              1443.00     2102.0
# Census_OEMModelIdentifier                           189641.75   247520.0
# Census_ProcessorCoreCount                                2.00        4.0
# Census_ProcessorManufacturerIdentifier                   5.00        5.0
# Census_ProcessorModelIdentifier                       1998.00     2500.0
# Census_PrimaryDiskTotalCapacity                     239372.00   476940.0
# Census_SystemVolumeTotalCapacity                    120775.00   249450.0
# Census_HasOpticalDiskDrive                               0.00        0.0
# Census_TotalPhysicalRAM                               4096.00     4096.0
# Census_InternalPrimaryDiagonalDisplaySizeInInches       13.90       15.5
# Census_InternalPrimaryDisplayResolutionHorizontal     1366.00     1366.0
# Census_InternalPrimaryDisplayResolutionVertical        768.00      768.0
# Census_InternalBatteryNumberOfCharges                    0.00        0.0
# Census_OSBuildNumber                                 15063.00    16299.0
# Census_OSBuildRevision                                 165.00      285.0
# Census_OSInstallLanguageIdentifier                       8.00        9.0
# Census_OSUILocaleIdentifier                             31.00       34.0
# Census_IsPortableOperatingSystem                         0.00        0.0
# Census_IsFlightingInternal                               0.00        0.0
# Census_IsFlightsDisabled                                 0.00        0.0
# Census_ThresholdOptIn                                    0.00        0.0
# Census_FirmwareManufacturerIdentifier                  142.00      500.0
# Census_FirmwareVersionIdentifier                     13156.00    33070.0
# Census_IsSecureBootEnabled                               0.00        0.0
# Census_IsWIMBootEnabled                                  0.00        0.0
# Census_IsVirtualDevice                                   0.00        0.0
# Census_IsTouchEnabled                                    0.00        0.0
# Census_IsPenCapable                                      0.00        0.0
# Census_IsAlwaysOnAlwaysConnectedCapable                  0.00        0.0
# Wdft_IsGamer                                             0.00        0.0
# Wdft_RegionIdentifier                                    3.00       10.0
# HasDetections                                            0.00        0.0
#
#                                                             75%           max
# Unnamed: 0                                         6.690936e+06  8.921471e+06
# IsBeta                                             0.000000e+00  1.000000e+00
# RtpStateBitfield                                   7.000000e+00  3.500000e+01
# IsSxsPassiveMode                                   0.000000e+00  1.000000e+00
# DefaultBrowsersIdentifier                          2.381000e+03  3.209000e+03
# AVProductStatesIdentifier                          5.344700e+04  7.049200e+04
# AVProductsInstalled                                2.000000e+00  5.000000e+00
# AVProductsEnabled                                  1.000000e+00  4.000000e+00
# HasTpm                                             1.000000e+00  1.000000e+00
# CountryIdentifier                                  1.620000e+02  2.220000e+02
# CityIdentifier                                     1.239395e+05  1.679580e+05
# OrganizationIdentifier                             2.700000e+01  5.200000e+01
# GeoNameIdentifier                                  2.670000e+02  2.960000e+02
# LocaleEnglishNameIdentifier                        1.820000e+02  2.830000e+02
# OsBuild                                            1.713400e+04  1.824200e+04
# OsSuite                                            7.680000e+02  7.840000e+02
# IsProtected                                        1.000000e+00  1.000000e+00
# AutoSampleOptIn                                    0.000000e+00  1.000000e+00
# SMode                                              0.000000e+00  1.000000e+00
# IeVerIdentifier                                    1.370000e+02  4.290000e+02
# Firewall                                           1.000000e+00  1.000000e+00
# UacLuaenable                                       1.000000e+00  6.357062e+06
# Census_OEMNameIdentifier                           2.668000e+03  6.143000e+03
# Census_OEMModelIdentifier                          3.044380e+05  3.454930e+05
# Census_ProcessorCoreCount                          4.000000e+00  8.800000e+01
# Census_ProcessorManufacturerIdentifier             5.000000e+00  1.000000e+01
# Census_ProcessorModelIdentifier                    2.877000e+03  4.472000e+03
# Census_PrimaryDiskTotalCapacity                    9.538690e+05  4.768767e+07
# Census_SystemVolumeTotalCapacity                   4.759810e+05  4.768710e+07
# Census_HasOpticalDiskDrive                         0.000000e+00  1.000000e+00
# Census_TotalPhysicalRAM                            8.192000e+03  3.932160e+05
# Census_InternalPrimaryDiagonalDisplaySizeInInches  1.720000e+01  1.420000e+02
# Census_InternalPrimaryDisplayResolutionHorizontal  1.920000e+03  1.152000e+04
# Census_InternalPrimaryDisplayResolutionVertical    1.080000e+03  4.320000e+03
# Census_InternalBatteryNumberOfCharges              4.294967e+09  4.294967e+09
# Census_OSBuildNumber                               1.713400e+04  1.824200e+04
# Census_OSBuildRevision                             5.470000e+02  1.906900e+04
# Census_OSInstallLanguageIdentifier                 2.000000e+01  3.900000e+01
# Census_OSUILocaleIdentifier                        9.000000e+01  1.620000e+02
# Census_IsPortableOperatingSystem                   0.000000e+00  1.000000e+00
# Census_IsFlightingInternal                         0.000000e+00  1.000000e+00
# Census_IsFlightsDisabled                           0.000000e+00  1.000000e+00
# Census_ThresholdOptIn                              0.000000e+00  1.000000e+00
# Census_FirmwareManufacturerIdentifier              5.560000e+02  1.084000e+03
# Census_FirmwareVersionIdentifier                   5.243600e+04  7.209100e+04
# Census_IsSecureBootEnabled                         1.000000e+00  1.000000e+00
# Census_IsWIMBootEnabled                            0.000000e+00  0.000000e+00
# Census_IsVirtualDevice                             0.000000e+00  1.000000e+00
# Census_IsTouchEnabled                              0.000000e+00  1.000000e+00
# Census_IsPenCapable                                0.000000e+00  1.000000e+00
# Census_IsAlwaysOnAlwaysConnectedCapable            0.000000e+00  1.000000e+00
# Wdft_IsGamer                                       1.000000e+00  1.000000e+00
# Wdft_RegionIdentifier                              1.100000e+01  1.500000e+01
# HasDetections                                      1.000000e+00  1.000000e+00

# %%
object_describe = df.describe(include='object').T
object_describe
# Out:
#                                    count  unique  \
# MachineIdentifier                 500000  500000
# ProductName                       500000       3
# EngineVersion                     500000      53
# AppVersion                        500000      95
# AvSigVersion                      500000    6455
# Platform                          500000       4
# Processor                         500000       3
# OsVer                             500000      21
# OsPlatformSubRelease              500000       9
# OsBuildLab                        499999     453
# SkuEdition                        500000       8
# SmartScreen                       321404      12
# Census_MDC2FormFactor             500000      12
# Census_DeviceFamily               500000       3
# Census_PrimaryDiskTypeName        499291       4
# Census_ChassisTypeName            499963      34
# Census_PowerPlatformRoleName      499998       9
# Census_InternalBatteryType        144397      28
# Census_OSVersion                  500000     305
# Census_OSArchitecture             500000       3
# Census_OSBranch                   500000      15
# Census_OSEdition                  500000      22
# Census_OSSkuName                  500000      21
# Census_OSInstallTypeName          500000       9
# Census_OSWUAutoUpdateOptionsName  500000       6
# Census_GenuineStateName           500000       4
# Census_ActivationChannel          500000       6
# Census_FlightRing                 500000       8
#
#                                                                        top  \
# MachineIdentifier                         f1cd864e97bae82bdf96523e1a539121
# ProductName                                                   win8defender
# EngineVersion                                                  1.1.15200.1
# AppVersion                                                 4.18.1807.18075
# AvSigVersion                                                  1.273.1420.0
# Platform                                                         windows10
# Processor                                                              x64
# OsVer                                                             10.0.0.0
# OsPlatformSubRelease                                                   rs4
# OsBuildLab                        17134.1.amd64fre.rs4_release.180410-1804
# SkuEdition                                                            Home
# SmartScreen                                                   RequireAdmin
# Census_MDC2FormFactor                                             Notebook
# Census_DeviceFamily                                        Windows.Desktop
# Census_PrimaryDiskTypeName                                             HDD
# Census_ChassisTypeName                                            Notebook
# Census_PowerPlatformRoleName                                        Mobile
# Census_InternalBatteryType                                            lion
# Census_OSVersion                                            10.0.17134.228
# Census_OSArchitecture                                                amd64
# Census_OSBranch                                                rs4_release
# Census_OSEdition                                                      Core
# Census_OSSkuName                                                      CORE
# Census_OSInstallTypeName                                        UUPUpgrade
# Census_OSWUAutoUpdateOptionsName                                  FullAuto
# Census_GenuineStateName                                         IS_GENUINE
# Census_ActivationChannel                                            Retail
# Census_FlightRing                                                   Retail
#
#                                     freq
# MachineIdentifier                      1
# ProductName                       494604
# EngineVersion                     216491
# AppVersion                        288809
# AvSigVersion                        5771
# Platform                          483048
# Processor                         454423
# OsVer                             483830
# OsPlatformSubRelease              220779
# OsBuildLab                        206436
# SkuEdition                        308567
# SmartScreen                       241594
# Census_MDC2FormFactor             320948
# Census_DeviceFamily               499183
# Census_PrimaryDiskTypeName        325429
# Census_ChassisTypeName            294232
# Census_PowerPlatformRoleName      346378
# Census_InternalBatteryType        113500
# Census_OSVersion                   79975
# Census_OSArchitecture             454435
# Census_OSBranch                   226001
# Census_OSEdition                  194469
# Census_OSSkuName                  194464
# Census_OSInstallTypeName          146780
# Census_OSWUAutoUpdateOptionsName  222482
# Census_GenuineStateName           441402
# Census_ActivationChannel          264932
# Census_FlightRing                 468299

# %%
df[df.duplicated(keep="first")]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, MachineIdentifier, ProductName, EngineVersion, AppVersion, AvSigVersion, IsBeta, RtpStateBitfield, IsSxsPassiveMode, DefaultBrowsersIdentifier, AVProductStatesIdentifier, AVProductsInstalled, AVProductsEnabled, HasTpm, CountryIdentifier, CityIdentifier, OrganizationIdentifier, GeoNameIdentifier, LocaleEnglishNameIdentifier, Platform, Processor, OsVer, OsBuild, OsSuite, OsPlatformSubRelease, OsBuildLab, SkuEdition, IsProtected, AutoSampleOptIn, PuaMode, SMode, IeVerIdentifier, SmartScreen, Firewall, UacLuaenable, Census_MDC2FormFactor, Census_DeviceFamily, Census_OEMNameIdentifier, Census_OEMModelIdentifier, Census_ProcessorCoreCount, Census_ProcessorManufacturerIdentifier, Census_ProcessorModelIdentifier, Census_ProcessorClass, Census_PrimaryDiskTotalCapacity, Census_PrimaryDiskTypeName, Census_SystemVolumeTotalCapacity, Census_HasOpticalDiskDrive, Census_TotalPhysicalRAM, Census_ChassisTypeName, Census_InternalPrimaryDiagonalDisplaySizeInInches, Census_InternalPrimaryDisplayResolutionHorizontal, Census_InternalPrimaryDisplayResolutionVertical, Census_PowerPlatformRoleName, Census_InternalBatteryType, Census_InternalBatteryNumberOfCharges, Census_OSVersion, Census_OSArchitecture, Census_OSBranch, Census_OSBuildNumber, Census_OSBuildRevision, Census_OSEdition, Census_OSSkuName, Census_OSInstallTypeName, Census_OSInstallLanguageIdentifier, Census_OSUILocaleIdentifier, Census_OSWUAutoUpdateOptionsName, Census_IsPortableOperatingSystem, Census_GenuineStateName, Census_ActivationChannel, Census_IsFlightingInternal, Census_IsFlightsDisabled, Census_FlightRing, Census_ThresholdOptIn, Census_FirmwareManufacturerIdentifier, Census_FirmwareVersionIdentifier, Census_IsSecureBootEnabled, Census_IsWIMBootEnabled, Census_IsVirtualDevice, Census_IsTouchEnabled, Census_IsPenCapable, Census_IsAlwaysOnAlwaysConnectedCapable, Wdft_IsGamer, Wdft_RegionIdentifier, HasDetections]
# Index: []
#
# [0 rows x 84 columns]

# %%
df.isna().sum()
# Out:
# Unnamed: 0                                                0
# MachineIdentifier                                         0
# ProductName                                               0
# EngineVersion                                             0
# AppVersion                                                0
# AvSigVersion                                              0
# IsBeta                                                    0
# RtpStateBitfield                                       1832
# IsSxsPassiveMode                                          0
# DefaultBrowsersIdentifier                            475939
# AVProductStatesIdentifier                              1938
# AVProductsInstalled                                    1938
# AVProductsEnabled                                      1938
# HasTpm                                                    0
# CountryIdentifier                                         0
# CityIdentifier                                        18240
# OrganizationIdentifier                               154563
# GeoNameIdentifier                                        16
# LocaleEnglishNameIdentifier                               0
# Platform                                                  0
# Processor                                                 0
# OsVer                                                     0
# OsBuild                                                   0
# OsSuite                                                   0
# OsPlatformSubRelease                                      0
# OsBuildLab                                                1
# SkuEdition                                                0
# IsProtected                                            1926
# AutoSampleOptIn                                           0
# PuaMode                                              499874
# SMode                                                 29848
# IeVerIdentifier                                        3209
# SmartScreen                                          178596
# Firewall                                               5162
# UacLuaenable                                            623
# Census_MDC2FormFactor                                     0
# Census_DeviceFamily                                       0
# Census_OEMNameIdentifier                               5381
# Census_OEMModelIdentifier                              5764
# Census_ProcessorCoreCount                              2347
# Census_ProcessorManufacturerIdentifier                 2347
# Census_ProcessorModelIdentifier                        2349
# Census_ProcessorClass                                497918
# Census_PrimaryDiskTotalCapacity                        2976
# Census_PrimaryDiskTypeName                              709
# Census_SystemVolumeTotalCapacity                       2976
# Census_HasOpticalDiskDrive                                0
# Census_TotalPhysicalRAM                                4556
# Census_ChassisTypeName                                   37
# Census_InternalPrimaryDiagonalDisplaySizeInInches      2654
# Census_InternalPrimaryDisplayResolutionHorizontal      2650
# Census_InternalPrimaryDisplayResolutionVertical        2650
# Census_PowerPlatformRoleName                              2
# Census_InternalBatteryType                           355603
# Census_InternalBatteryNumberOfCharges                 15038
# Census_OSVersion                                          0
# Census_OSArchitecture                                     0
# Census_OSBranch                                           0
# Census_OSBuildNumber                                      0
# Census_OSBuildRevision                                    0
# Census_OSEdition                                          0
# Census_OSSkuName                                          0
# Census_OSInstallTypeName                                  0
# Census_OSInstallLanguageIdentifier                     3332
# Census_OSUILocaleIdentifier                               0
# Census_OSWUAutoUpdateOptionsName                          0
# Census_IsPortableOperatingSystem                          0
# Census_GenuineStateName                                   0
# Census_ActivationChannel                                  0
# Census_IsFlightingInternal                           415225
# Census_IsFlightsDisabled                               8933
# Census_FlightRing                                         0
# Census_ThresholdOptIn                                318104
# Census_FirmwareManufacturerIdentifier                 10349
# Census_FirmwareVersionIdentifier                       9061
# Census_IsSecureBootEnabled                                0
# Census_IsWIMBootEnabled                              317666
# Census_IsVirtualDevice                                  901
# Census_IsTouchEnabled                                     0
# Census_IsPenCapable                                       0
# Census_IsAlwaysOnAlwaysConnectedCapable                4040
# Wdft_IsGamer                                          16950
# Wdft_RegionIdentifier                                 16950
# HasDetections                                             0
# dtype: int64

# %%
df.drop(columns = ['Unnamed: 0', 'MachineIdentifier'], axis=1, inplace=True)

# %% [markdown]
# ### 1.1. Definición de target

# %%
target = "HasDetections"

# %% [markdown]
# ### 1.2. Adición de columnas por cálculo de otras

# %%
# --- Feature Engineering ---
# Operaciones deterministas (sin estadísticos) → no introduce data leakage


# 1. Ratio AV: proporción de antivirus habilitados sobre instalados
df["av_enabled_ratio"] = df["AVProductsEnabled"] / df["AVProductsInstalled"]

# 2. Resolución total de pantalla
df["screen_resolution"] = (
    df["Census_InternalPrimaryDisplayResolutionHorizontal"] *
    df["Census_InternalPrimaryDisplayResolutionVertical"]
)

# 3. Versión mayor de AppVersion
df["app_version_major"] = pd.to_numeric(
    df["AppVersion"].str.split(".").str[0], errors="coerce"
)

print(f"Shape tras FE: {df.shape}")

# %% [markdown]
# ## 2. Separación validación, test y train

# %% [markdown]
# Se empleará el método stratification para mantener la distribución del target ya que está balanceado

# %%
from sklearn.model_selection import train_test_split

X = df.drop(target, axis=1)
y = df[target]

# Step 1: Create Validation set (15%)
X_temp, X_val, y_temp, y_val = train_test_split(
    X, y,
    test_size=75000,  # 15% of total
    stratify=y,
    random_state=42
)

# Step 2: Create TEST set (15% of total)

X_train, X_test, y_train, y_test = train_test_split(
    X_temp, y_temp,
    test_size=75000, # 15% of total
    stratify=y_temp,
    random_state=42
)

# %%
print("Train:", y_train.value_counts(normalize=True))
print("Val:", y_val.value_counts(normalize=True))
print("Test:", y_test.value_counts(normalize=True))
# Out:
# Train: HasDetections
# 0    0.500094
# 1    0.499906
# Name: proportion, dtype: float64
# Val: HasDetections
# 0    0.500093
# 1    0.499907
# Name: proportion, dtype: float64
# Test: HasDetections
# 0    0.500093
# 1    0.499907
# Name: proportion, dtype: float64

# %%
np.save("train_idx.npy", X_train.index)
np.save("val_idx.npy", X_val.index)
np.save("test_idx.npy", X_test.index)

# %%
df_train = X_train.copy()
df_train[target] = y_train

# %% [markdown]
# ## 3. EDA + Gestión de nulos

# %%
class EDAInspector:
    #DecisionTree version
    def __init__(self, df):
        self.df = df.copy()
        # self.refresh_types()
    
        # Lists to track treated columns
        self.fill_constant_list = []
        self.fill_mean_list = []
        self.fill_median_list = []
        self.fill_missing_list = []
        #self.missing_indicator_list = []
        self.drop_columns = []
        #self.dropped_nanRows_columns = []
    
    
    @property
    def numeric_cols(self):
        return self.df.select_dtypes(include=np.number).columns.tolist()

    @property
    def object_cols(self):
        return self.df.select_dtypes(include=["object"]).columns.tolist()

    @property
    def category_cols(self):
        return self.df.select_dtypes(include=["category"]).columns.tolist()

    @property
    def bool_cols(self):
        return self.df.select_dtypes(include=["bool"]).columns.tolist()

    @property
    def n_rows(self):
        return len(self.df)

    
    @property #se emplea como propiedad para que se ejecute automáticamente al acceder a ella, sin necesidad de llamarla como método
    def high_cardinality_cols(self):

        cat_cols = self.object_cols + self.category_cols

        unique_counts = self.df[cat_cols].nunique()

        return unique_counts[unique_counts > 100].index.tolist()
    
    # ----------------------------
    # NUMERIC SUMMARY
    # ----------------------------
    
    def numeric_summary(self):
        
        summary = pd.DataFrame({
            "dtype": self.df[self.numeric_cols].dtypes,
            "unique_values": self.df[self.numeric_cols].nunique(),
            "pct_unique": self.df[self.numeric_cols].nunique() / self.n_rows * 100,
            "null_pct": self.df[self.numeric_cols].isnull().mean() * 100,
            "min": self.df[self.numeric_cols].min(),
            "max": self.df[self.numeric_cols].max()
        })
        
        summary["possible_id"] = summary["pct_unique"] > 90
        
        summary["likely_categorical"] = (
            (summary["unique_values"] < 60) &
            (summary["pct_unique"] < 5)
        )
        
        # Store likely_categorical columns as a list for easy access
        self.likely_categorical_cols = summary[summary["likely_categorical"]].index.tolist()
        
        return summary.sort_values("pct_unique", ascending=False)
    
    
    # ----------------------------
    # CATEGORICAL SUMMARY
    # ----------------------------
    
    def categorical_summary(self):

        cat_cols = self.object_cols + self.category_cols

        summary = pd.DataFrame({
            "dtype": self.df[cat_cols].dtypes,
            "unique_values": self.df[cat_cols].nunique(),
            "pct_unique": self.df[cat_cols].nunique() / self.n_rows * 100,
            "null_pct": self.df[cat_cols].isnull().mean() * 100
        })

        summary["high_cardinality"] = summary.index.isin(self.high_cardinality_cols)

        return summary.sort_values("unique_values", ascending=False)
    
    # ----------------------------
    # Identifier/Version etc DETECTOR in numeric columns
    # ---------------------------- 
    
    def detect_identifier_columns(self, keywords=None):
    
        if keywords is None:
            keywords = ["identifier"]
        
        self.identifier_cols = [
            col for col in self.numeric_cols
            if any(k in col.lower() for k in keywords)
        ]
        
        print(f"Detected {len(self.identifier_cols)} identifier columns:")
        #print(self.identifier_cols)
        
        return self.identifier_cols
 
    
    # ----------------------------
    # CONVERT NUMERIC → CATEGORY
    # ----------------------------
    
    def convert_to_category(self, columns, verbose=True):
        
        if isinstance(columns, str):
            columns = [columns]
        
        for col in columns:
            if col in self.df.columns:
                self.df[col] = self.df[col].astype("category")
        
        #self.refresh_types()
        
        if verbose:
            print(len(columns), " converted to category:", columns)
    
    
    # ----------------------------
    # CONVERT TO NUMERIC
    # ----------------------------
    
    def convert_to_numeric(self, columns, verbose=True):
        
        if isinstance(columns, str):
            columns = [columns]
        
        for col in columns:
            if col in self.df.columns:
                self.df[col] = pd.to_numeric(self.df[col], errors="coerce")
        
        #self.refresh_types()
        
        if verbose:
            print(len(columns), " converted to numeric:", columns)



    def null_summary(self, only_nulls = False):
        self.summary = pd.DataFrame({
            "dtype": self.df.dtypes,
            "null_count": self.df.isnull().sum(),
            "pct_nulls": self.df.isnull().mean() * 100,
            "unique_values": self.df.nunique(),
            "pct_unique": self.df.nunique() / self.n_rows * 100
        })
        
        result = self.summary.sort_values("pct_nulls", ascending=False)
        
        if only_nulls:
            result = result[result["null_count"]>0]
            
        return result
    
    def apply_drops(self, columns=None, verbose=True):
        """
        Drop columns from the DataFrame.
        
        Parameters
        ----------
        columns : str or list, optional
            Column or list of columns to drop. If None, drops whatever is already
            stored in self.drop_columns.
        """

        # Normalize input
        if columns is not None:
            if isinstance(columns, str):
                columns = [columns]

            # Add new columns to drop list
            self.drop_columns.extend(columns)

        # Remove duplicates
        self.drop_columns = list(set(self.drop_columns))

        # Determine which columns actually exist in df
        cols_to_drop = [c for c in self.drop_columns if c in self.df.columns]

        if cols_to_drop:
            self.df.drop(columns=cols_to_drop, inplace=True)
            if verbose:
                print(f"Dropped {len(cols_to_drop)} columns: {cols_to_drop}")
        else:
            if verbose:
                print("No matching columns to drop.")

    # Refresh internal type lists
    #self.refresh_types()
    
       
    def droppable_columns(
        self,
        null_high_thresh=95,
        null_low_thresh=0.5,
        cardinality_threshold=90
    ):
        """
        Classifies columns into:
        - high null percentage → drop
        - high cardinality → drop
        - low nulls → fill (categorical → 'Missing', numeric → median)
        """

        null_sum = self.null_summary()

        # -------------------------
        # 1. HIGH NULL COLUMNS → DROP
        # -------------------------
        high_null_cols = null_sum[null_sum["pct_nulls"] > null_high_thresh].index.tolist()

        # -------------------------
        # 2. HIGH CARDINALITY → DROP
        # -------------------------
        high_cardinality_cols = null_sum[null_sum["pct_unique"] > cardinality_threshold].index.tolist()

        # -------------------------
        # 3. LOW NULL COLUMNS → FILL
        # -------------------------
        low_null_cols = null_sum[
            (null_sum["pct_nulls"] > 0) &
            (null_sum["pct_nulls"] < null_low_thresh)
        ].index.tolist()

        # Split low-null columns by dtype
        low_null_categorical = [c for c in low_null_cols if c in self.object_cols + self.category_cols]
        low_null_numeric = [c for c in low_null_cols if c in self.numeric_cols]

        # -------------------------
        # 4. Apply actions
        # -------------------------

        # Drop high-null and high-cardinality columns
        cols_to_drop = high_null_cols + high_cardinality_cols
        if cols_to_drop:
            self.drop_columns.extend(cols_to_drop)

        # Fill categorical with "Missing" because DecisionTree handles it
        for col in low_null_categorical:
            self.fill_missing_list.append(col)

        # Fill numeric with median
        for col in low_null_numeric:
            self.fill_median_list.append(col)

        # Apply the drops immediately
        self.apply_drops(verbose=False)
        
        # -------------------------
        # 5. Logging
        # -------------------------
        print(f"{len(high_null_cols)} columns dropped due to high null percentage: {high_null_cols}")
        print(f"{len(high_cardinality_cols)} columns dropped due to high cardinality: {high_cardinality_cols}")
        print(f"{len(low_null_categorical)} categorical columns added to fill_missing_list : {low_null_categorical}")
        print(f"{len(low_null_numeric)} numeric columns added to fill_median_list: {low_null_numeric}")

        #self.refresh_types()
      
    
    def imputation_summary(self):
        """
        Build a summary DataFrame showing:
        - columns dropped
        - columns filled with constant / mean / median
        - columns still containing nulls (not treated)
        - remaining untouched columns
        """

        # Ensure lists are flat
        drop = sorted(set(self.drop_columns))
        fill_constant = sorted(set(self.fill_constant_list))
        fill_mean = sorted(set(self.fill_mean_list))
        fill_median = sorted(set(self.fill_median_list))
        fill_missing = sorted(set(self.fill_missing_list))

        # Columns with nulls that were NOT treated
        treated = set(drop + fill_constant + fill_mean + fill_median + fill_missing)
        null_cols = self.df.columns[self.df.isnull().any()].tolist()
        self.remaining_null_cols = sorted(set(null_cols) - treated)

        # Untouched columns = all columns - treated - remaining_null_cols
        self.untouched = sorted(set(self.df.columns) - treated - set(self.remaining_null_cols))

        # Build dictionary
        summary_dict = {
            "drop_columns": drop,
            "fill_constant": fill_constant,
            "fill_mean": fill_mean,
            "fill_median": fill_median,
            "fill_missing": fill_missing,
            "remaining_null_columns": self.remaining_null_cols,
            "untouched_columns": self.untouched
        }

        # Build DataFrame
        rows = []
        for category, cols in summary_dict.items():
            if cols:
                dtypes = sorted({str(self.df[col].dtype) for col in cols if col in self.df.columns})
            else:
                dtypes = []

            rows.append({
                "category": category,
                "n_columns": len(cols),
                "columns": cols,
                "dtypes": dtypes
            })

        return pd.DataFrame(rows)

        
    def get_data(self):
        return self.df

# %% [markdown]
# ### 3.1. Inspector1 para primer EDA

# %%
inspector1 = EDAInspector(df_train)

# %%
inspector1.numeric_summary()
# Out:
#                                                      dtype  unique_values  \
# Census_SystemVolumeTotalCapacity                   float64         112810
# Census_OEMModelIdentifier                          float64          33296
# CityIdentifier                                     float64          31181
# Census_FirmwareVersionIdentifier                   float64          20897
# AVProductStatesIdentifier                          float64           4466
# Census_InternalBatteryNumberOfCharges              float64           4031
# Census_ProcessorModelIdentifier                    float64           2127
# Census_OEMNameIdentifier                           float64           1406
# Census_PrimaryDiskTotalCapacity                    float64            906
# Census_InternalPrimaryDiagonalDisplaySizeInInches  float64            483
# DefaultBrowsersIdentifier                          float64            469
# Census_TotalPhysicalRAM                            float64            449
# Census_InternalPrimaryDisplayResolutionVertical    float64            420
# Census_InternalPrimaryDisplayResolutionHorizontal  float64            374
# Census_FirmwareManufacturerIdentifier              float64            276
# GeoNameIdentifier                                  float64            263
# Census_OSBuildRevision                               int64            237
# LocaleEnglishNameIdentifier                          int64            225
# CountryIdentifier                                    int64            222
# IeVerIdentifier                                    float64            167
# Census_OSUILocaleIdentifier                          int64             83
# Census_OSBuildNumber                                 int64             54
# OsBuild                                              int64             44
# OrganizationIdentifier                             float64             43
# Census_OSInstallLanguageIdentifier                 float64             39
# Census_ProcessorCoreCount                          float64             27
# Wdft_RegionIdentifier                              float64             15
# OsSuite                                              int64              9
# RtpStateBitfield                                   float64              7
# AVProductsEnabled                                  float64              5
# AVProductsInstalled                                float64              5
# UacLuaenable                                       float64              5
# Census_ProcessorManufacturerIdentifier             float64              4
# HasTpm                                               int64              2
# AutoSampleOptIn                                      int64              2
# IsSxsPassiveMode                                     int64              2
# SMode                                              float64              2
# Census_IsSecureBootEnabled                           int64              2
# Firewall                                           float64              2
# IsProtected                                        float64              2
# Census_HasOpticalDiskDrive                           int64              2
# Census_IsFlightsDisabled                           float64              2
# Census_IsFlightingInternal                         float64              2
# Census_ThresholdOptIn                              float64              2
# Census_IsPortableOperatingSystem                     int64              2
# Wdft_IsGamer                                       float64              2
# Census_IsVirtualDevice                             float64              2
# Census_IsPenCapable                                  int64              2
# Census_IsTouchEnabled                                int64              2
# HasDetections                                        int64              2
# Census_IsAlwaysOnAlwaysConnectedCapable            float64              2
# IsBeta                                               int64              1
# Census_IsWIMBootEnabled                            float64              1
#
#                                                    pct_unique   null_pct  \
# Census_SystemVolumeTotalCapacity                    32.231429   0.595143
# Census_OEMModelIdentifier                            9.513143   1.150000
# CityIdentifier                                       8.908857   3.626000
# Census_FirmwareVersionIdentifier                     5.970571   1.812857
# AVProductStatesIdentifier                            1.276000   0.386000
# Census_InternalBatteryNumberOfCharges                1.151714   3.003143
# Census_ProcessorModelIdentifier                      0.607714   0.469143
# Census_OEMNameIdentifier                             0.401714   1.068571
# Census_PrimaryDiskTotalCapacity                      0.258857   0.595143
# Census_InternalPrimaryDiagonalDisplaySizeInInches    0.138000   0.534000
# DefaultBrowsersIdentifier                            0.134000  95.179143
# Census_TotalPhysicalRAM                              0.128286   0.896857
# Census_InternalPrimaryDisplayResolutionVertical      0.120000   0.533429
# Census_InternalPrimaryDisplayResolutionHorizontal    0.106857   0.533429
# Census_FirmwareManufacturerIdentifier                0.078857   2.072571
# GeoNameIdentifier                                    0.075143   0.003714
# Census_OSBuildRevision                               0.067714   0.000000
# LocaleEnglishNameIdentifier                          0.064286   0.000000
# CountryIdentifier                                    0.063429   0.000000
# IeVerIdentifier                                      0.047714   0.637714
# Census_OSUILocaleIdentifier                          0.023714   0.000000
# Census_OSBuildNumber                                 0.015429   0.000000
# OsBuild                                              0.012571   0.000000
# OrganizationIdentifier                               0.012286  30.939429
# Census_OSInstallLanguageIdentifier                   0.011143   0.667143
# Census_ProcessorCoreCount                            0.007714   0.468571
# Wdft_RegionIdentifier                                0.004286   3.414000
# OsSuite                                              0.002571   0.000000
# RtpStateBitfield                                     0.002000   0.368571
# AVProductsEnabled                                    0.001429   0.386000
# AVProductsInstalled                                  0.001429   0.386000
# UacLuaenable                                         0.001429   0.123143
# Census_ProcessorManufacturerIdentifier               0.001143   0.468571
# HasTpm                                               0.000571   0.000000
# AutoSampleOptIn                                      0.000571   0.000000
# IsSxsPassiveMode                                     0.000571   0.000000
# SMode                                                0.000571   5.974286
# Census_IsSecureBootEnabled                           0.000571   0.000000
# Firewall                                             0.000571   1.032857
# IsProtected                                          0.000571   0.384286
# Census_HasOpticalDiskDrive                           0.000571   0.000000
# Census_IsFlightsDisabled                             0.000571   1.783143
# Census_IsFlightingInternal                           0.000571  83.038286
# Census_ThresholdOptIn                                0.000571  63.641714
# Census_IsPortableOperatingSystem                     0.000571   0.000000
# Wdft_IsGamer                                         0.000571   3.414000
# Census_IsVirtualDevice                               0.000571   0.181714
# Census_IsPenCapable                                  0.000571   0.000000
# Census_IsTouchEnabled                                0.000571   0.000000
# HasDetections                                        0.000571   0.000000
# Census_IsAlwaysOnAlwaysConnectedCapable              0.000571   0.804000
# IsBeta                                               0.000286   0.000000
# Census_IsWIMBootEnabled                              0.000286  63.558857
#
#                                                        min           max  \
# Census_SystemVolumeTotalCapacity                    9689.0  2.859558e+07
# Census_OEMModelIdentifier                             22.0  3.454930e+05
# CityIdentifier                                         7.0  1.679580e+05
# Census_FirmwareVersionIdentifier                      10.0  7.209100e+04
# AVProductStatesIdentifier                              3.0  7.049200e+04
# Census_InternalBatteryNumberOfCharges                  0.0  4.294967e+09
# Census_ProcessorModelIdentifier                       19.0  4.472000e+03
# Census_OEMNameIdentifier                              74.0  6.143000e+03
# Census_PrimaryDiskTotalCapacity                    10240.0  2.859591e+07
# Census_InternalPrimaryDiagonalDisplaySizeInInches      4.9  1.420000e+02
# DefaultBrowsersIdentifier                              1.0  3.209000e+03
# Census_TotalPhysicalRAM                              512.0  3.932160e+05
# Census_InternalPrimaryDisplayResolutionVertical       -1.0  4.320000e+03
# Census_InternalPrimaryDisplayResolutionHorizontal     -1.0  1.152000e+04
# Census_FirmwareManufacturerIdentifier                 11.0  1.084000e+03
# GeoNameIdentifier                                      1.0  2.960000e+02
# Census_OSBuildRevision                                 0.0  1.906900e+04
# LocaleEnglishNameIdentifier                            1.0  2.830000e+02
# CountryIdentifier                                      1.0  2.220000e+02
# IeVerIdentifier                                        8.0  4.290000e+02
# Census_OSUILocaleIdentifier                            1.0  1.620000e+02
# Census_OSBuildNumber                                9600.0  1.824200e+04
# OsBuild                                             7600.0  1.824200e+04
# OrganizationIdentifier                                 1.0  5.200000e+01
# Census_OSInstallLanguageIdentifier                     1.0  3.900000e+01
# Census_ProcessorCoreCount                              1.0  8.800000e+01
# Wdft_RegionIdentifier                                  1.0  1.500000e+01
# OsSuite                                               16.0  7.840000e+02
# RtpStateBitfield                                       0.0  3.500000e+01
# AVProductsEnabled                                      0.0  4.000000e+00
# AVProductsInstalled                                    1.0  5.000000e+00
# UacLuaenable                                           0.0  6.357062e+06
# Census_ProcessorManufacturerIdentifier                 1.0  1.000000e+01
# HasTpm                                                 0.0  1.000000e+00
# AutoSampleOptIn                                        0.0  1.000000e+00
# IsSxsPassiveMode                                       0.0  1.000000e+00
# SMode                                                  0.0  1.000000e+00
# Census_IsSecureBootEnabled                             0.0  1.000000e+00
# Firewall                                               0.0  1.000000e+00
# IsProtected                                            0.0  1.000000e+00
# Census_HasOpticalDiskDrive                             0.0  1.000000e+00
# Census_IsFlightsDisabled                               0.0  1.000000e+00
# Census_IsFlightingInternal                             0.0  1.000000e+00
# Census_ThresholdOptIn                                  0.0  1.000000e+00
# Census_IsPortableOperatingSystem                       0.0  1.000000e+00
# Wdft_IsGamer                                           0.0  1.000000e+00
# Census_IsVirtualDevice                                 0.0  1.000000e+00
# Census_IsPenCapable                                    0.0  1.000000e+00
# Census_IsTouchEnabled                                  0.0  1.000000e+00
# HasDetections                                          0.0  1.000000e+00
# Census_IsAlwaysOnAlwaysConnectedCapable                0.0  1.000000e+00
# IsBeta                                                 0.0  0.000000e+00
# Census_IsWIMBootEnabled                                0.0  0.000000e+00
#
#                                                    possible_id  \
# Census_SystemVolumeTotalCapacity                         False
# Census_OEMModelIdentifier                                False
# CityIdentifier                                           False
# Census_FirmwareVersionIdentifier                         False
# AVProductStatesIdentifier                                False
# Census_InternalBatteryNumberOfCharges                    False
# Census_ProcessorModelIdentifier                          False
# Census_OEMNameIdentifier                                 False
# Census_PrimaryDiskTotalCapacity                          False
# Census_InternalPrimaryDiagonalDisplaySizeInInches        False
# DefaultBrowsersIdentifier                                False
# Census_TotalPhysicalRAM                                  False
# Census_InternalPrimaryDisplayResolutionVertical          False
# Census_InternalPrimaryDisplayResolutionHorizontal        False
# Census_FirmwareManufacturerIdentifier                    False
# GeoNameIdentifier                                        False
# Census_OSBuildRevision                                   False
# LocaleEnglishNameIdentifier                              False
# CountryIdentifier                                        False
# IeVerIdentifier                                          False
# Census_OSUILocaleIdentifier                              False
# Census_OSBuildNumber                                     False
# OsBuild                                                  False
# OrganizationIdentifier                                   False
# Census_OSInstallLanguageIdentifier                       False
# Census_ProcessorCoreCount                                False
# Wdft_RegionIdentifier                                    False
# OsSuite                                                  False
# RtpStateBitfield                                         False
# AVProductsEnabled                                        False
# AVProductsInstalled                                      False
# UacLuaenable                                             False
# Census_ProcessorManufacturerIdentifier                   False
# HasTpm                                                   False
# AutoSampleOptIn                                          False
# IsSxsPassiveMode                                         False
# SMode                                                    False
# Census_IsSecureBootEnabled                               False
# Firewall                                                 False
# IsProtected                                              False
# Census_HasOpticalDiskDrive                               False
# Census_IsFlightsDisabled                                 False
# Census_IsFlightingInternal                               False
# Census_ThresholdOptIn                                    False
# Census_IsPortableOperatingSystem                         False
# Wdft_IsGamer                                             False
# Census_IsVirtualDevice                                   False
# Census_IsPenCapable                                      False
# Census_IsTouchEnabled                                    False
# HasDetections                                            False
# Census_IsAlwaysOnAlwaysConnectedCapable                  False
# IsBeta                                                   False
# Census_IsWIMBootEnabled                                  False
#
#                                                    likely_categorical
# Census_SystemVolumeTotalCapacity                                False
# Census_OEMModelIdentifier                                       False
# CityIdentifier                                                  False
# Census_FirmwareVersionIdentifier                                False
# AVProductStatesIdentifier                                       False
# Census_InternalBatteryNumberOfCharges                           False
# Census_ProcessorModelIdentifier                                 False
# Census_OEMNameIdentifier                                        False
# Census_PrimaryDiskTotalCapacity                                 False
# Census_InternalPrimaryDiagonalDisplaySizeInInches               False
# DefaultBrowsersIdentifier                                       False
# Census_TotalPhysicalRAM                                         False
# Census_InternalPrimaryDisplayResolutionVertical                 False
# Census_InternalPrimaryDisplayResolutionHorizontal               False
# Census_FirmwareManufacturerIdentifier                           False
# GeoNameIdentifier                                               False
# Census_OSBuildRevision                                          False
# LocaleEnglishNameIdentifier                                     False
# CountryIdentifier                                               False
# IeVerIdentifier                                                 False
# Census_OSUILocaleIdentifier                                     False
# Census_OSBuildNumber                                             True
# OsBuild                                                          True
# OrganizationIdentifier                                           True
# Census_OSInstallLanguageIdentifier                               True
# Census_ProcessorCoreCount                                        True
# Wdft_RegionIdentifier                                            True
# OsSuite                                                          True
# RtpStateBitfield                                                 True
# AVProductsEnabled                                                True
# AVProductsInstalled                                              True
# UacLuaenable                                                     True
# Census_ProcessorManufacturerIdentifier                           True
# HasTpm                                                           True
# AutoSampleOptIn                                                  True
# IsSxsPassiveMode                                                 True
# SMode                                                            True
# Census_IsSecureBootEnabled                                       True
# Firewall                                                         True
# IsProtected                                                      True
# Census_HasOpticalDiskDrive                                       True
# Census_IsFlightsDisabled                                         True
# Census_IsFlightingInternal                                       True
# Census_ThresholdOptIn                                            True
# Census_IsPortableOperatingSystem                                 True
# Wdft_IsGamer                                                     True
# Census_IsVirtualDevice                                           True
# Census_IsPenCapable                                              True
# Census_IsTouchEnabled                                            True
# HasDetections                                                    True
# Census_IsAlwaysOnAlwaysConnectedCapable                          True
# IsBeta                                                           True
# Census_IsWIMBootEnabled                                          True

# %%
inspector1.likely_categorical_cols
# Out:
# ['IsBeta',
#  'RtpStateBitfield',
#  'IsSxsPassiveMode',
#  'AVProductsInstalled',
#  'AVProductsEnabled',
#  'HasTpm',
#  'OrganizationIdentifier',
#  'OsBuild',
#  'OsSuite',
#  'IsProtected',
#  'AutoSampleOptIn',
#  'SMode',
#  'Firewall',
#  'UacLuaenable',
#  'Census_ProcessorCoreCount',
#  'Census_ProcessorManufacturerIdentifier',
#  'Census_HasOpticalDiskDrive',
#  'Census_OSBuildNumber',
#  'Census_OSInstallLanguageIdentifier',
#  'Census_IsPortableOperatingSystem',
#  'Census_IsFlightingInternal',
#  'Census_IsFlightsDisabled',
#  'Census_ThresholdOptIn',
#  'Census_IsSecureBootEnabled',
#  'Census_IsWIMBootEnabled',
#  'Census_IsVirtualDevice',
#  'Census_IsTouchEnabled',
#  'Census_IsPenCapable',
#  'Census_IsAlwaysOnAlwaysConnectedCapable',
#  'Wdft_IsGamer',
#  'Wdft_RegionIdentifier',
#  'HasDetections']

# %%
inspector1.convert_to_category(inspector1.likely_categorical_cols)
# Out:
# 32  converted to category: ['IsBeta', 'RtpStateBitfield', 'IsSxsPassiveMode', 'AVProductsInstalled', 'AVProductsEnabled', 'HasTpm', 'OrganizationIdentifier', 'OsBuild', 'OsSuite', 'IsProtected', 'AutoSampleOptIn', 'SMode', 'Firewall', 'UacLuaenable', 'Census_ProcessorCoreCount', 'Census_ProcessorManufacturerIdentifier', 'Census_HasOpticalDiskDrive', 'Census_OSBuildNumber', 'Census_OSInstallLanguageIdentifier', 'Census_IsPortableOperatingSystem', 'Census_IsFlightingInternal', 'Census_IsFlightsDisabled', 'Census_ThresholdOptIn', 'Census_IsSecureBootEnabled', 'Census_IsWIMBootEnabled', 'Census_IsVirtualDevice', 'Census_IsTouchEnabled', 'Census_IsPenCapable', 'Census_IsAlwaysOnAlwaysConnectedCapable', 'Wdft_IsGamer', 'Wdft_RegionIdentifier', 'HasDetections']

# %%
inspector1.detect_identifier_columns()
# Out:
# Detected 13 identifier columns:
# ['DefaultBrowsersIdentifier',
#  'AVProductStatesIdentifier',
#  'CountryIdentifier',
#  'CityIdentifier',
#  'GeoNameIdentifier',
#  'LocaleEnglishNameIdentifier',
#  'IeVerIdentifier',
#  'Census_OEMNameIdentifier',
#  'Census_OEMModelIdentifier',
#  'Census_ProcessorModelIdentifier',
#  'Census_OSUILocaleIdentifier',
#  'Census_FirmwareManufacturerIdentifier',
#  'Census_FirmwareVersionIdentifier']

# %%
inspector1.convert_to_category(inspector1.identifier_cols)
# Out:
# 13  converted to category: ['DefaultBrowsersIdentifier', 'AVProductStatesIdentifier', 'CountryIdentifier', 'CityIdentifier', 'GeoNameIdentifier', 'LocaleEnglishNameIdentifier', 'IeVerIdentifier', 'Census_OEMNameIdentifier', 'Census_OEMModelIdentifier', 'Census_ProcessorModelIdentifier', 'Census_OSUILocaleIdentifier', 'Census_FirmwareManufacturerIdentifier', 'Census_FirmwareVersionIdentifier']

# %%
inspector1.droppable_columns()
# Out:
# 3 columns dropped due to high null percentage: ['PuaMode', 'Census_ProcessorClass', 'DefaultBrowsersIdentifier']
# 0 columns dropped due to high cardinality: []
# 14 categorical columns added to fill_missing_list : ['Census_ProcessorModelIdentifier', 'Census_ProcessorManufacturerIdentifier', 'Census_ProcessorCoreCount', 'AVProductsEnabled', 'AVProductsInstalled', 'AVProductStatesIdentifier', 'IsProtected', 'RtpStateBitfield', 'Census_IsVirtualDevice', 'Census_PrimaryDiskTypeName', 'UacLuaenable', 'Census_ChassisTypeName', 'GeoNameIdentifier', 'OsBuildLab']
# 0 numeric columns added to fill_median_list: []

# %%
inspector1.numeric_summary()
# Out:
#                                                      dtype  unique_values  \
# Census_SystemVolumeTotalCapacity                   float64         112810
# Census_InternalBatteryNumberOfCharges              float64           4031
# Census_PrimaryDiskTotalCapacity                    float64            906
# Census_InternalPrimaryDiagonalDisplaySizeInInches  float64            483
# Census_TotalPhysicalRAM                            float64            449
# Census_InternalPrimaryDisplayResolutionVertical    float64            420
# Census_InternalPrimaryDisplayResolutionHorizontal  float64            374
# Census_OSBuildRevision                               int64            237
#
#                                                    pct_unique  null_pct  \
# Census_SystemVolumeTotalCapacity                    32.231429  0.595143
# Census_InternalBatteryNumberOfCharges                1.151714  3.003143
# Census_PrimaryDiskTotalCapacity                      0.258857  0.595143
# Census_InternalPrimaryDiagonalDisplaySizeInInches    0.138000  0.534000
# Census_TotalPhysicalRAM                              0.128286  0.896857
# Census_InternalPrimaryDisplayResolutionVertical      0.120000  0.533429
# Census_InternalPrimaryDisplayResolutionHorizontal    0.106857  0.533429
# Census_OSBuildRevision                               0.067714  0.000000
#
#                                                        min           max  \
# Census_SystemVolumeTotalCapacity                    9689.0  2.859558e+07
# Census_InternalBatteryNumberOfCharges                  0.0  4.294967e+09
# Census_PrimaryDiskTotalCapacity                    10240.0  2.859591e+07
# Census_InternalPrimaryDiagonalDisplaySizeInInches      4.9  1.420000e+02
# Census_TotalPhysicalRAM                              512.0  3.932160e+05
# Census_InternalPrimaryDisplayResolutionVertical       -1.0  4.320000e+03
# Census_InternalPrimaryDisplayResolutionHorizontal     -1.0  1.152000e+04
# Census_OSBuildRevision                                 0.0  1.906900e+04
#
#                                                    possible_id  \
# Census_SystemVolumeTotalCapacity                         False
# Census_InternalBatteryNumberOfCharges                    False
# Census_PrimaryDiskTotalCapacity                          False
# Census_InternalPrimaryDiagonalDisplaySizeInInches        False
# Census_TotalPhysicalRAM                                  False
# Census_InternalPrimaryDisplayResolutionVertical          False
# Census_InternalPrimaryDisplayResolutionHorizontal        False
# Census_OSBuildRevision                                   False
#
#                                                    likely_categorical
# Census_SystemVolumeTotalCapacity                                False
# Census_InternalBatteryNumberOfCharges                           False
# Census_PrimaryDiskTotalCapacity                                 False
# Census_InternalPrimaryDiagonalDisplaySizeInInches               False
# Census_TotalPhysicalRAM                                         False
# Census_InternalPrimaryDisplayResolutionVertical                 False
# Census_InternalPrimaryDisplayResolutionHorizontal               False
# Census_OSBuildRevision                                          False

# %%
#Census_InternalBatteryNumberOfCharges correlation check, drop suspicious
inspector1.df[target].corr(inspector1.df.Census_InternalBatteryNumberOfCharges)
# Out:
# np.float64(0.01995231376898978)

# %%
inspector1.categorical_summary()
# Out:
#                                             dtype  unique_values  pct_unique  \
# Census_OEMModelIdentifier                category          33296    9.513143
# CityIdentifier                           category          31181    8.908857
# Census_FirmwareVersionIdentifier         category          20897    5.970571
# AvSigVersion                               object           5925    1.692857
# AVProductStatesIdentifier                category           4466    1.276000
# Census_ProcessorModelIdentifier          category           2127    0.607714
# Census_OEMNameIdentifier                 category           1406    0.401714
# OsBuildLab                                 object            431    0.123143
# Census_OSVersion                           object            292    0.083429
# Census_FirmwareManufacturerIdentifier    category            276    0.078857
# GeoNameIdentifier                        category            263    0.075143
# LocaleEnglishNameIdentifier              category            225    0.064286
# CountryIdentifier                        category            222    0.063429
# IeVerIdentifier                          category            167    0.047714
# AppVersion                                 object             93    0.026571
# Census_OSUILocaleIdentifier              category             83    0.023714
# Census_OSBuildNumber                     category             54    0.015429
# EngineVersion                              object             52    0.014857
# OsBuild                                  category             44    0.012571
# OrganizationIdentifier                   category             43    0.012286
# Census_OSInstallLanguageIdentifier       category             39    0.011143
# Census_ChassisTypeName                     object             33    0.009429
# Census_InternalBatteryType                 object             27    0.007714
# Census_ProcessorCoreCount                category             27    0.007714
# Census_OSEdition                           object             19    0.005429
# Census_OSSkuName                           object             18    0.005143
# OsVer                                      object             17    0.004857
# Census_OSBranch                            object             15    0.004286
# Wdft_RegionIdentifier                    category             15    0.004286
# SmartScreen                                object             12    0.003429
# Census_MDC2FormFactor                      object             11    0.003143
# OsPlatformSubRelease                       object              9    0.002571
# Census_OSInstallTypeName                   object              9    0.002571
# Census_PowerPlatformRoleName               object              9    0.002571
# OsSuite                                  category              9    0.002571
# SkuEdition                                 object              8    0.002286
# RtpStateBitfield                         category              7    0.002000
# Census_FlightRing                          object              7    0.002000
# Census_OSWUAutoUpdateOptionsName           object              6    0.001714
# Census_ActivationChannel                   object              6    0.001714
# AVProductsEnabled                        category              5    0.001429
# AVProductsInstalled                      category              5    0.001429
# UacLuaenable                             category              5    0.001429
# Census_ProcessorManufacturerIdentifier   category              4    0.001143
# Census_PrimaryDiskTypeName                 object              4    0.001143
# Platform                                   object              4    0.001143
# Census_GenuineStateName                    object              4    0.001143
# Census_DeviceFamily                        object              3    0.000857
# Processor                                  object              3    0.000857
# Census_OSArchitecture                      object              3    0.000857
# ProductName                                object              2    0.000571
# Census_HasOpticalDiskDrive               category              2    0.000571
# HasTpm                                   category              2    0.000571
# IsSxsPassiveMode                         category              2    0.000571
# AutoSampleOptIn                          category              2    0.000571
# Census_IsSecureBootEnabled               category              2    0.000571
# IsProtected                              category              2    0.000571
# SMode                                    category              2    0.000571
# Firewall                                 category              2    0.000571
# Census_IsFlightsDisabled                 category              2    0.000571
# Census_IsFlightingInternal               category              2    0.000571
# Census_ThresholdOptIn                    category              2    0.000571
# Census_IsPortableOperatingSystem         category              2    0.000571
# Wdft_IsGamer                             category              2    0.000571
# Census_IsVirtualDevice                   category              2    0.000571
# Census_IsPenCapable                      category              2    0.000571
# Census_IsTouchEnabled                    category              2    0.000571
# HasDetections                            category              2    0.000571
# Census_IsAlwaysOnAlwaysConnectedCapable  category              2    0.000571
# IsBeta                                   category              1    0.000286
# Census_IsWIMBootEnabled                  category              1    0.000286
#
#                                           null_pct  high_cardinality
# Census_OEMModelIdentifier                 1.150000              True
# CityIdentifier                            3.626000              True
# Census_FirmwareVersionIdentifier          1.812857              True
# AvSigVersion                              0.000000              True
# AVProductStatesIdentifier                 0.386000              True
# Census_ProcessorModelIdentifier           0.469143              True
# Census_OEMNameIdentifier                  1.068571              True
# OsBuildLab                                0.000286              True
# Census_OSVersion                          0.000000              True
# Census_FirmwareManufacturerIdentifier     2.072571              True
# GeoNameIdentifier                         0.003714              True
# LocaleEnglishNameIdentifier               0.000000              True
# CountryIdentifier                         0.000000              True
# IeVerIdentifier                           0.637714              True
# AppVersion                                0.000000             False
# Census_OSUILocaleIdentifier               0.000000             False
# Census_OSBuildNumber                      0.000000             False
# EngineVersion                             0.000000             False
# OsBuild                                   0.000000             False
# OrganizationIdentifier                   30.939429             False
# Census_OSInstallLanguageIdentifier        0.667143             False
# Census_ChassisTypeName                    0.008000             False
# Census_InternalBatteryType               71.154857             False
# Census_ProcessorCoreCount                 0.468571             False
# Census_OSEdition                          0.000000             False
# Census_OSSkuName                          0.000000             False
# OsVer                                     0.000000             False
# Census_OSBranch                           0.000000             False
# Wdft_RegionIdentifier                     3.414000             False
# SmartScreen                              35.758000             False
# Census_MDC2FormFactor                     0.000000             False
# OsPlatformSubRelease                      0.000000             False
# Census_OSInstallTypeName                  0.000000             False
# Census_PowerPlatformRoleName              0.000000             False
# OsSuite                                   0.000000             False
# SkuEdition                                0.000000             False
# RtpStateBitfield                          0.368571             False
# Census_FlightRing                         0.000000             False
# Census_OSWUAutoUpdateOptionsName          0.000000             False
# Census_ActivationChannel                  0.000000             False
# AVProductsEnabled                         0.386000             False
# AVProductsInstalled                       0.386000             False
# UacLuaenable                              0.123143             False
# Census_ProcessorManufacturerIdentifier    0.468571             False
# Census_PrimaryDiskTypeName                0.142286             False
# Platform                                  0.000000             False
# Census_GenuineStateName                   0.000000             False
# Census_DeviceFamily                       0.000000             False
# Processor                                 0.000000             False
# Census_OSArchitecture                     0.000000             False
# ProductName                               0.000000             False
# Census_HasOpticalDiskDrive                0.000000             False
# HasTpm                                    0.000000             False
# IsSxsPassiveMode                          0.000000             False
# AutoSampleOptIn                           0.000000             False
# Census_IsSecureBootEnabled                0.000000             False
# IsProtected                               0.384286             False
# SMode                                     5.974286             False
# Firewall                                  1.032857             False
# Census_IsFlightsDisabled                  1.783143             False
# Census_IsFlightingInternal               83.038286             False
# Census_ThresholdOptIn                    63.641714             False
# Census_IsPortableOperatingSystem          0.000000             False
# Wdft_IsGamer                              3.414000             False
# Census_IsVirtualDevice                    0.181714             False
# Census_IsPenCapable                       0.000000             False
# Census_IsTouchEnabled                     0.000000             False
# HasDetections                             0.000000             False
# Census_IsAlwaysOnAlwaysConnectedCapable   0.804000             False
# IsBeta                                    0.000000             False
# Census_IsWIMBootEnabled                  63.558857             False

# %%
inspector1.imputation_summary()
# Out:
#                  category  n_columns  \
# 0            drop_columns          3
# 1           fill_constant          0
# 2               fill_mean          0
# 3             fill_median          0
# 4            fill_missing         14
# 5  remaining_null_columns         26
# 6       untouched_columns         39
#
#                                              columns  \
# 0  [Census_ProcessorClass, DefaultBrowsersIdentif...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [AVProductStatesIdentifier, AVProductsEnabled,...
# 5  [Census_FirmwareManufacturerIdentifier, Census...
# 6  [AppVersion, AutoSampleOptIn, AvSigVersion, Ce...
#
#                         dtypes
# 0                           []
# 1                           []
# 2                           []
# 3                           []
# 4           [category, object]
# 5  [category, float64, object]
# 6    [category, int64, object]

# %% [markdown]
# ### 3.2. Check signal function

# %%
#This functions helps us check the impact of a column on the target variable, both for null values and for the different values of the column.

def check_signal(df, col, target=target):
    print("Value counts:")
    print(df[col].value_counts(dropna=False, normalize=True))
    
    print("\nNull impact:")
    print(df.groupby(df[col].isnull())[target].mean())
    
    print("\nValue impact:")
    print(df.groupby(col)[target].mean().sort_values())

# %% [markdown]
# ### 3.3. Columnas con >30% y <95% nulos

# %% [markdown]
# #### Census_IsFlightingInternal:
# Es una propiedad del servicio "Device Census", pero no un toggle que cambie el comportamiento de Windows defender (no muestra posibles diferencias en detección de Malware). Dado el alto porcentaje de nulos y que casi no tiene variabilidad en los valores nulos se elimina

# %%
check_signal(df_train, 'Census_IsFlightingInternal')
# Out:
# Value counts:
# Census_IsFlightingInternal
# NaN    0.830383
# 0.0    0.169614
# 1.0    0.000003
# Name: proportion, dtype: float64
#
# Null impact:
# Census_IsFlightingInternal
# False    0.485935
# True     0.502759
# Name: HasDetections, dtype: float64
#
# Value impact:
# Census_IsFlightingInternal
# 1.0    0.000000
# 0.0    0.485943
# Name: HasDetections, dtype: float64

# %%
inspector1.drop_columns.append('Census_IsFlightingInternal')

# %% [markdown]
# #### Drop Census_InternalBatteryType. Alta Cardinalidad

# %%
#Add missing category
df_train['Census_InternalBatteryType'].value_counts(dropna = False, normalize = True)
# Out:
# Census_InternalBatteryType
# NaN     0.711549
# lion    0.226729
# li-i    0.027700
# #       0.020306
# lip     0.006626
# liio    0.003537
# li p    0.000969
# li      0.000734
# nimh    0.000577
# real    0.000311
# bq20    0.000294
# pbac    0.000257
# vbox    0.000186
# lgi0    0.000051
# unkn    0.000040
# lipo    0.000034
# lhp0    0.000023
# ram     0.000014
# 4cel    0.000011
# lipp    0.000009
# ithi    0.000009
# batt    0.000009
# bad     0.000006
# a132    0.000006
# virt    0.000006
# icp3    0.000003
# 3ion    0.000003
# lgl0    0.000003
# Name: proportion, dtype: float64

# %%
check_signal(df_train, 'Census_InternalBatteryType')
# Out:
# Value counts:
# Census_InternalBatteryType
# NaN     0.711549
# lion    0.226729
# li-i    0.027700
# #       0.020306
# lip     0.006626
# liio    0.003537
# li p    0.000969
# li      0.000734
# nimh    0.000577
# real    0.000311
# bq20    0.000294
# pbac    0.000257
# vbox    0.000186
# lgi0    0.000051
# unkn    0.000040
# lipo    0.000034
# lhp0    0.000023
# ram     0.000014
# 4cel    0.000011
# lipp    0.000009
# ithi    0.000009
# batt    0.000009
# bad     0.000006
# a132    0.000006
# virt    0.000006
# icp3    0.000003
# 3ion    0.000003
# lgl0    0.000003
# Name: proportion, dtype: float64
#
# Null impact:
# Census_InternalBatteryType
# False    0.485331
# True     0.505814
# Name: HasDetections, dtype: float64
#
# Value impact:
# Census_InternalBatteryType
# 3ion    0.000000
# 4cel    0.000000
# batt    0.000000
# virt    0.000000
# ram     0.200000
# vbox    0.230769
# lhp0    0.250000
# bq20    0.252427
# ithi    0.333333
# lipo    0.416667
# nimh    0.420792
# li      0.443580
# liio    0.464459
# pbac    0.466667
# lion    0.481104
# li-i    0.483136
# li p    0.486726
# a132    0.500000
# bad     0.500000
# unkn    0.500000
# real    0.504587
# #       0.529478
# lip     0.545063
# lgi0    0.555556
# lipp    0.666667
# icp3    1.000000
# lgl0    1.000000
# Name: HasDetections, dtype: float64

# %%
inspector1.drop_columns.append('Census_InternalBatteryType')

# %% [markdown]
# #### Census_ThresholdOptIn se elimina al ser un toggle de envío de información a la base de datos de Windows Defender y no un setting de detección de malware. (Además del alto porcentaje de nulos)
# Is an internal registry value used by Windows to manage your participation in Windows Insider "Census" data collection. It is not a standard security setting within the Windows Defender/Security interface that you "opt-in" to for better protection.
# Instead, this value tracks whether your device meets the "threshold" for certain diagnostic and telemetry reporting required for Insider preview builds of Windows.

# %%
check_signal(df_train, 'Census_ThresholdOptIn')
# Out:
# Value counts:
# Census_ThresholdOptIn
# NaN    0.636417
# 0.0    0.363489
# 1.0    0.000094
# Name: proportion, dtype: float64
#
# Null impact:
# Census_ThresholdOptIn
# False    0.490020
# True     0.505553
# Name: HasDetections, dtype: float64
#
# Value impact:
# Census_ThresholdOptIn
# 0.0    0.490013
# 1.0    0.515152
# Name: HasDetections, dtype: float64

# %%
inspector1.drop_columns.append('Census_ThresholdOptIn')

# %% [markdown]
# #### Census_IsWIMBootEnabled: se elimina puesto que en los no nulos sólo hay 1 valor y la señal entre Nan y 0 es parecida

# %%
check_signal(df_train, 'Census_IsWIMBootEnabled')
# Out:
# Value counts:
# Census_IsWIMBootEnabled
# NaN    0.635589
# 0.0    0.364411
# Name: proportion, dtype: float64
#
# Null impact:
# Census_IsWIMBootEnabled
# False    0.490027
# True     0.505570
# Name: HasDetections, dtype: float64
#
# Value impact:
# Census_IsWIMBootEnabled
# 0.0    0.490027
# Name: HasDetections, dtype: float64

# %%
inspector1.drop_columns.append('Census_IsWIMBootEnabled')

# %% [markdown]
# #### SmartScreen:
# Variable categórica que se imputará con valor 'missing'. Tiene catagorías con alto valor de señal Warn, On, ExistsNotSet y este último tiene 11% de valores del dataset. Puede ser una feature importante.

# %%
#Add missing category
check_signal(df_train, 'SmartScreen')
# Out:
# Value counts:
# SmartScreen
# RequireAdmin    0.482746
# NaN             0.357580
# ExistsNotSet    0.117029
# Off             0.020803
# Warn            0.015063
# Prompt          0.003934
# Block           0.002517
# off             0.000140
# On              0.000106
# &#x02;          0.000037
# &#x01;          0.000026
# on              0.000017
# requireadmin    0.000003
# Name: proportion, dtype: float64
#
# Null impact:
# SmartScreen
# False    0.510561
# True     0.480764
# Name: HasDetections, dtype: float64
#
# Value impact:
# SmartScreen
# requireadmin    0.000000
# &#x01;          0.222222
# RequireAdmin    0.439101
# Off             0.482901
# Prompt          0.484386
# on              0.500000
# Block           0.501703
# &#x02;          0.538462
# off             0.551020
# Warn            0.572269
# On              0.702703
# ExistsNotSet    0.803223
# Name: HasDetections, dtype: float64

# %%
inspector1.fill_missing_list.append('SmartScreen')

# %% [markdown]
# #### OrganizationIdentifier:  ID for the organization the machine belongs in, organization ID is mapped to both specific companies and broad industries
# La columna se tratará como categorical y los nulos se imputarán como 'missing'.

# %%
check_signal(df_train, 'OrganizationIdentifier')
# Out:
# Value counts:
# OrganizationIdentifier
# 27.0    0.469929
# NaN     0.309394
# 18.0    0.197289
# 48.0    0.007357
# 50.0    0.005120
# 11.0    0.002074
# 37.0    0.002066
# 49.0    0.001414
# 46.0    0.001277
# 14.0    0.000534
# 32.0    0.000437
# 36.0    0.000423
# 33.0    0.000366
# 52.0    0.000337
# 2.0     0.000309
# 5.0     0.000209
# 40.0    0.000191
# 28.0    0.000183
# 4.0     0.000160
# 10.0    0.000143
# 51.0    0.000103
# 1.0     0.000089
# 20.0    0.000071
# 8.0     0.000066
# 47.0    0.000057
# 3.0     0.000051
# 22.0    0.000046
# 6.0     0.000043
# 39.0    0.000043
# 31.0    0.000037
# 21.0    0.000029
# 16.0    0.000023
# 42.0    0.000023
# 19.0    0.000020
# 44.0    0.000017
# 7.0     0.000017
# 29.0    0.000014
# 26.0    0.000011
# 43.0    0.000009
# 45.0    0.000006
# 41.0    0.000006
# 35.0    0.000003
# 25.0    0.000003
# 23.0    0.000003
# Name: proportion, dtype: float64
#
# Null impact:
# OrganizationIdentifier
# False    0.501183
# True     0.497054
# Name: HasDetections, dtype: float64
#
# Value impact:
# OrganizationIdentifier
# 25.0    0.000000
# 23.0    0.000000
# 16.0    0.250000
# 19.0    0.285714
# 21.0    0.300000
# 43.0    0.333333
# 22.0    0.375000
# 1.0     0.387097
# 3.0     0.388889
# 6.0     0.400000
# 2.0     0.407407
# 10.0    0.420000
# 32.0    0.424837
# 4.0     0.446429
# 47.0    0.450000
# 33.0    0.453125
# 28.0    0.453125
# 37.0    0.457815
# 31.0    0.461538
# 14.0    0.465241
# 5.0     0.465753
# 51.0    0.472222
# 49.0    0.480808
# 40.0    0.492537
# 27.0    0.498434
# 7.0     0.500000
# 44.0    0.500000
# 45.0    0.500000
# 41.0    0.500000
# 18.0    0.505177
# 46.0    0.514541
# 48.0    0.514951
# 52.0    0.516949
# 20.0    0.520000
# 11.0    0.526171
# 39.0    0.533333
# 36.0    0.587838
# 29.0    0.600000
# 50.0    0.612723
# 8.0     0.739130
# 42.0    0.750000
# 26.0    0.750000
# 35.0    1.000000
# Name: HasDetections, dtype: float64

# %%
inspector1.fill_missing_list.append('OrganizationIdentifier')

# %% [markdown]
# ### 3.4. Columnas <30% nulos

# %%
#inspector1.show_nulls()

# %% [markdown]
# #### Fillna to missing (Decision tree trabaja bien con categoría 'missing')
# SMode: Dados los resultados, aun con pocos valores '1', indican mucha menor media de detección que los '0'.
#
# Wdft_IsGamer: mayor detección de malware en Gamer = '1'.
#
# Census_IsAlwaysOnAlwaysConnectedCapable: menor detección de malware en valor = '1'.
#
# Firewall: no hay tendencia clara, missing se asigna a moda '0'.

# %%
check_signal(df_train, 'SMode')
# Out:
# Value counts:
# SMode
# 0.0    0.939809
# NaN    0.059743
# 1.0    0.000449
# Name: proportion, dtype: float64
#
# Null impact:
# SMode
# False    0.505102
# True     0.418125
# Name: HasDetections, dtype: float64
#
# Value impact:
# SMode
# 1.0    0.197452
# 0.0    0.505249
# Name: HasDetections, dtype: float64

# %%
#Dados los resultados, se decide imputar los missing values de SMode con la moda (0)
inspector1.fill_constant_list.append('SMode')

# %%
check_signal(df_train, 'Wdft_IsGamer')
# Out:
# Value counts:
# Wdft_IsGamer
# 0.0    0.69138
# 1.0    0.27448
# NaN    0.03414
# Name: proportion, dtype: float64
#
# Null impact:
# Wdft_IsGamer
# False    0.499067
# True     0.523642
# Name: HasDetections, dtype: float64
#
# Value impact:
# Wdft_IsGamer
# 0.0    0.480761
# 1.0    0.545176
# Name: HasDetections, dtype: float64

# %%
inspector1.fill_constant_list.append('Wdft_IsGamer')

# %%
check_signal(df_train, 'Census_IsAlwaysOnAlwaysConnectedCapable')
# Out:
# Value counts:
# Census_IsAlwaysOnAlwaysConnectedCapable
# 0.0    0.935211
# 1.0    0.056749
# NaN    0.008040
# Name: proportion, dtype: float64
#
# Null impact:
# Census_IsAlwaysOnAlwaysConnectedCapable
# False    0.499732
# True     0.521322
# Name: HasDetections, dtype: float64
#
# Value impact:
# Census_IsAlwaysOnAlwaysConnectedCapable
# 1.0    0.369953
# 0.0    0.507607
# Name: HasDetections, dtype: float64

# %%
inspector1.fill_constant_list.append('Census_IsAlwaysOnAlwaysConnectedCapable')

# %%
check_signal(df_train, 'Firewall')
# Out:
# Value counts:
# Firewall
# 1.0    0.967997
# 0.0    0.021674
# NaN    0.010329
# Name: proportion, dtype: float64
#
# Null impact:
# Firewall
# False    0.500010
# True     0.489903
# Name: HasDetections, dtype: float64
#
# Value impact:
# Firewall
# 0.0    0.491959
# 1.0    0.500190
# Name: HasDetections, dtype: float64

# %%
inspector1.fill_constant_list.append('Firewall')

# %% [markdown]
# #### Boolean column Census_IsFlightsDisabled: solo 6 values ='1' y poca señal, ee elimina.

# %%
check_signal(df_train, 'Census_IsFlightsDisabled')
# Out:
# Value counts:
# Census_IsFlightsDisabled
# 0.0    0.982151
# NaN    0.017831
# 1.0    0.000017
# Name: proportion, dtype: float64
#
# Null impact:
# Census_IsFlightsDisabled
# False    0.499804
# True     0.505528
# Name: HasDetections, dtype: float64
#
# Value impact:
# Census_IsFlightsDisabled
# 1.0    0.000000
# 0.0    0.499812
# Name: HasDetections, dtype: float64

# %%
inspector1.drop_columns.append('Census_IsFlightsDisabled')

# %% [markdown]
# ### 3.5. Other columns to drop

# %%
# Eliminamos columnas que no aportan información relevante, tienen alta cardinalidad o alta tasa de nulos que dificultaría su imputación
cols_to_drop = [
    'AutoSampleOptIn',                   # correlación prácticamente 0 con target
    'Census_IsPortableOperatingSystem',  # 99.95% es 0, sin varianza
    #'SMode',                             # 99.96% es 0, sin varianza
    'CityIdentifier',                    # alta cardinalidad (37,157 valores únicos)
    'OsBuildLab',                        # info redundante. Misma info en OsBuild, OsVer, Processor por separado
    'AvSigVersion',                      # alta cardinalidad (6,455), redundante con EngineVersion
    'Census_OSVersion'                  # redundante con Census_OSBuildNumber y OsVer
]

# %% [markdown]
# ### 3.5. Summary

# %%
inspector1.apply_drops(cols_to_drop)
# Out:
# Dropped 11 columns: ['CityIdentifier', 'AvSigVersion', 'OsBuildLab', 'Census_IsWIMBootEnabled', 'Census_InternalBatteryType', 'Census_OSVersion', 'AutoSampleOptIn', 'Census_IsFlightingInternal', 'Census_IsFlightsDisabled', 'Census_ThresholdOptIn', 'Census_IsPortableOperatingSystem']

# %%
inspector1.imputation_summary()
# Out:
#                  category  n_columns  \
# 0            drop_columns         14
# 1           fill_constant          4
# 2               fill_mean          0
# 3             fill_median          0
# 4            fill_missing         16
# 5  remaining_null_columns         14
# 6       untouched_columns         35
#
#                                              columns  \
# 0  [AutoSampleOptIn, AvSigVersion, Census_Interna...
# 1  [Census_IsAlwaysOnAlwaysConnectedCapable, Fire...
# 2                                                 []
# 3                                                 []
# 4  [AVProductStatesIdentifier, AVProductsEnabled,...
# 5  [Census_FirmwareManufacturerIdentifier, Census...
# 6  [AppVersion, Census_ActivationChannel, Census_...
#
#                       dtypes
# 0                         []
# 1                 [category]
# 2                         []
# 3                         []
# 4         [category, object]
# 5        [category, float64]
# 6  [category, int64, object]

# %%
inspector1.df.describe().T
# Out:
#                                                       count          mean  \
# Census_PrimaryDiskTotalCapacity                    347917.0  5.137781e+05
# Census_SystemVolumeTotalCapacity                   347917.0  3.777762e+05
# Census_TotalPhysicalRAM                            346861.0  6.125380e+03
# Census_InternalPrimaryDiagonalDisplaySizeInInches  348131.0  1.669789e+01
# Census_InternalPrimaryDisplayResolutionHorizontal  348133.0  1.548004e+03
# Census_InternalPrimaryDisplayResolutionVertical    348133.0  8.981447e+02
# Census_InternalBatteryNumberOfCharges              339489.0  1.125179e+09
# Census_OSBuildRevision                             350000.0  9.654192e+02
#
#                                                             std      min  \
# Census_PrimaryDiskTotalCapacity                    3.658208e+05  10240.0
# Census_SystemVolumeTotalCapacity                   3.341645e+05   9689.0
# Census_TotalPhysicalRAM                            4.945160e+03    512.0
# Census_InternalPrimaryDiagonalDisplaySizeInInches  5.981516e+00      4.9
# Census_InternalPrimaryDisplayResolutionHorizontal  3.692134e+02     -1.0
# Census_InternalPrimaryDisplayResolutionVertical    2.147049e+02     -1.0
# Census_InternalBatteryNumberOfCharges              1.888541e+09      0.0
# Census_OSBuildRevision                             2.914660e+03      0.0
#
#                                                         25%       50%  \
# Census_PrimaryDiskTotalCapacity                    238475.0  476940.0
# Census_SystemVolumeTotalCapacity                   120754.0  249434.0
# Census_TotalPhysicalRAM                              4096.0    4096.0
# Census_InternalPrimaryDiagonalDisplaySizeInInches      13.9      15.5
# Census_InternalPrimaryDisplayResolutionHorizontal    1366.0    1366.0
# Census_InternalPrimaryDisplayResolutionVertical       768.0     768.0
# Census_InternalBatteryNumberOfCharges                   0.0       0.0
# Census_OSBuildRevision                                165.0     285.0
#
#                                                             75%           max
# Census_PrimaryDiskTotalCapacity                    9.538690e+05  2.859591e+07
# Census_SystemVolumeTotalCapacity                   4.759790e+05  2.859558e+07
# Census_TotalPhysicalRAM                            8.192000e+03  3.932160e+05
# Census_InternalPrimaryDiagonalDisplaySizeInInches  1.720000e+01  1.420000e+02
# Census_InternalPrimaryDisplayResolutionHorizontal  1.920000e+03  1.152000e+04
# Census_InternalPrimaryDisplayResolutionVertical    1.080000e+03  4.320000e+03
# Census_InternalBatteryNumberOfCharges              4.294967e+09  4.294967e+09
# Census_OSBuildRevision                             5.470000e+02  1.906900e+04

# %% [markdown]
# ## 4. Análisis de variables

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.size'] = 14  # tamaño global de letra

sample = X_train.sample(10000, random_state=42)

fig, axes = plt.subplots(nrows=len(inspector1.numeric_cols)//4 + 1, ncols=4, figsize=(24, len(inspector1.numeric_cols)*3))
axes = axes.flatten()

for i, col in enumerate(inspector1.numeric_cols):
    axes[i].boxplot(sample[col].dropna())
    axes[i].set_title(col, fontsize=12)
    axes[i].tick_params(axis='both', labelsize=10)

for j in range(i+1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Modelling

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class RareCategoryGrouper(BaseEstimator, TransformerMixin):
    
    def __init__(self, min_freq=0.01):
        self.min_freq = min_freq
    
    def fit(self, X, y=None):
        self.frequent_categories_ = {}

        if not isinstance(X, pd.DataFrame):
            X = pd.DataFrame(X)

        X = X.astype(str).copy()
        
        for col in X.columns:
            freq = X[col].value_counts(normalize=True)
            self.frequent_categories_[col] = set(freq[freq >= self.min_freq].index)
        
        return self
    
    def transform(self, X):
        # Preserve column names if DataFrame, else assign generic
        if isinstance(X, pd.DataFrame):
            X_trans = X.copy()
            cols = X.columns
        else:
            X_trans = pd.DataFrame(X.copy())
            cols = X_trans.columns  # 0..n-1

        for col in cols:
            frequent = self.frequent_categories_.get(col)
            if frequent is None:
                continue  # skip columns not fitted
            X_trans[col] = X_trans[col].astype(str).where(
                X_trans[col].astype(str).isin(frequent),
                "Other"
            )

        return X_trans
    
class FrequencyEncoder(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass

    def fit(self, X, y=None):
        self.freq_maps_ = {}
        if not isinstance(X, pd.DataFrame):
            X = pd.DataFrame(X)
        for col in X.columns:
            freq = X[col].value_counts(normalize=True)
            self.freq_maps_[col] = freq
        return self

    def transform(self, X):
        if not isinstance(X, pd.DataFrame):
            X_trans = pd.DataFrame(X.copy())
    
        else:
            X_trans = X.copy()

        for col in X_trans.columns:
            freq_map = self.freq_maps_.get(col)
            if freq_map is None:
                continue  # skip columns not fitted
            X_trans[col] = X_trans[col].map(freq_map).fillna(0)
        return X_trans

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import set_config
set_config(transform_output="pandas") #Para mantener el output de los transformers como DataFrame, lo que facilita la inspección y depuración de los datos a lo largo del pipeline.

# %% [markdown]
# ### 5.1. Preprocessing Lists for Pipelines

# %%
# Then extract the column lists
numeric_cols = list(inspector1.numeric_cols)
categorical_cols = list(inspector1.object_cols) + list(inspector1.category_cols)
categorical_cols.remove(target)

high_cardinality_cols = list(inspector1.high_cardinality_cols)
low_cardinality_cols = list(set(categorical_cols) - set(high_cardinality_cols))

# %% [markdown]
# ### 5.2. Preprocessing Pipelines

# %% [markdown]
# - Se ha estado trabajando para poder hacer una separación entre las columnas para hacer diferentes imputaciones en una "impute_pipe" y otra diferente para una "transform_pipe".
#
# - Sin embargo, dado que se realizarían diferentes clasificaciones de columnas y dado el riesgo de que pudiera aparecer el mismo nombre de columna en dos procesos de la pipeline diferentes, se ha decidido preservar la asignación por grupos de la pipeline de transformación de numérico, categorica de baja cardinalidad y categorica de alta cardinalidad.
#
# - De esta forma, se ha decidido reducir la complicación de la asignación de nulos: numérica --> mediana y categórica --> 'missing'.
#
# - Se podrían añadir grupos dentro de la lista low_cat_cols para asignación de las variables con pocos nulos y comportamiento 'bool'.

# %%
numeric_pipeline = ColumnTransformer([
    ("median", SimpleImputer(strategy="median"), numeric_cols)
])

# %%
low_cardinality_pipeline = Pipeline([
    
    ("imputer", SimpleImputer(strategy="constant", fill_value="Missing")),
    
    ("rare_grouper", RareCategoryGrouper(min_freq=0.01)),
    
    ("OHE", OneHotEncoder(handle_unknown="ignore", sparse_output=False))
])

# %%
high_cardinality_pipeline = Pipeline([
    
    ("imputer", SimpleImputer(strategy="constant", fill_value="Missing")),
    
    ("freq_encoder", FrequencyEncoder())
])

# %%
preprocessor = ColumnTransformer(
    transformers = [
    
        ("num", numeric_pipeline, numeric_cols),

        ("low_cat", low_cardinality_pipeline, low_cardinality_cols),
        
        ("high_cat", high_cardinality_pipeline, high_cardinality_cols)
    ],
    remainder="drop",
    n_jobs=1

)

# %%
low_cardinality_cols
# Out:
# ['AppVersion',
#  'Processor',
#  'Census_IsPenCapable',
#  'SkuEdition',
#  'IsBeta',
#  'Census_OSInstallTypeName',
#  'OsPlatformSubRelease',
#  'Census_HasOpticalDiskDrive',
#  'ProductName',
#  'Census_OSUILocaleIdentifier',
#  'Census_OSInstallLanguageIdentifier',
#  'Census_IsTouchEnabled',
#  'UacLuaenable',
#  'AVProductsEnabled',
#  'EngineVersion',
#  'Census_OSBuildNumber',
#  'Census_DeviceFamily',
#  'Census_MDC2FormFactor',
#  'Wdft_IsGamer',
#  'Census_OSArchitecture',
#  'Platform',
#  'Census_ProcessorCoreCount',
#  'HasTpm',
#  'SMode',
#  'Census_OSBranch',
#  'Census_ActivationChannel',
#  'SmartScreen',
#  'Census_OSSkuName',
#  'Census_OSEdition',
#  'Census_IsAlwaysOnAlwaysConnectedCapable',
#  'Firewall',
#  'IsSxsPassiveMode',
#  'Census_IsSecureBootEnabled',
#  'Census_PrimaryDiskTypeName',
#  'OsVer',
#  'OrganizationIdentifier',
#  'Census_ChassisTypeName',
#  'Census_IsVirtualDevice',
#  'Census_ProcessorManufacturerIdentifier',
#  'Census_GenuineStateName',
#  'IsProtected',
#  'OsSuite',
#  'Census_OSWUAutoUpdateOptionsName',
#  'Census_PowerPlatformRoleName',
#  'AVProductsInstalled',
#  'OsBuild',
#  'RtpStateBitfield',
#  'Wdft_RegionIdentifier',
#  'Census_FlightRing']

# %%
inspector1.categorical_summary()
# Out:
#                                             dtype  unique_values  pct_unique  \
# Census_OEMModelIdentifier                category          33296    9.513143
# Census_FirmwareVersionIdentifier         category          20897    5.970571
# AVProductStatesIdentifier                category           4466    1.276000
# Census_ProcessorModelIdentifier          category           2127    0.607714
# Census_OEMNameIdentifier                 category           1406    0.401714
# Census_FirmwareManufacturerIdentifier    category            276    0.078857
# GeoNameIdentifier                        category            263    0.075143
# LocaleEnglishNameIdentifier              category            225    0.064286
# CountryIdentifier                        category            222    0.063429
# IeVerIdentifier                          category            167    0.047714
# AppVersion                                 object             93    0.026571
# Census_OSUILocaleIdentifier              category             83    0.023714
# Census_OSBuildNumber                     category             54    0.015429
# EngineVersion                              object             52    0.014857
# OsBuild                                  category             44    0.012571
# OrganizationIdentifier                   category             43    0.012286
# Census_OSInstallLanguageIdentifier       category             39    0.011143
# Census_ChassisTypeName                     object             33    0.009429
# Census_ProcessorCoreCount                category             27    0.007714
# Census_OSEdition                           object             19    0.005429
# Census_OSSkuName                           object             18    0.005143
# OsVer                                      object             17    0.004857
# Wdft_RegionIdentifier                    category             15    0.004286
# Census_OSBranch                            object             15    0.004286
# SmartScreen                                object             12    0.003429
# Census_MDC2FormFactor                      object             11    0.003143
# Census_OSInstallTypeName                   object              9    0.002571
# OsPlatformSubRelease                       object              9    0.002571
# OsSuite                                  category              9    0.002571
# Census_PowerPlatformRoleName               object              9    0.002571
# SkuEdition                                 object              8    0.002286
# RtpStateBitfield                         category              7    0.002000
# Census_FlightRing                          object              7    0.002000
# Census_ActivationChannel                   object              6    0.001714
# Census_OSWUAutoUpdateOptionsName           object              6    0.001714
# UacLuaenable                             category              5    0.001429
# AVProductsEnabled                        category              5    0.001429
# AVProductsInstalled                      category              5    0.001429
# Platform                                   object              4    0.001143
# Census_ProcessorManufacturerIdentifier   category              4    0.001143
# Census_PrimaryDiskTypeName                 object              4    0.001143
# Census_GenuineStateName                    object              4    0.001143
# Census_DeviceFamily                        object              3    0.000857
# Processor                                  object              3    0.000857
# Census_OSArchitecture                      object              3    0.000857
# Census_HasOpticalDiskDrive               category              2    0.000571
# ProductName                                object              2    0.000571
# IsSxsPassiveMode                         category              2    0.000571
# SMode                                    category              2    0.000571
# IsProtected                              category              2    0.000571
# Firewall                                 category              2    0.000571
# HasTpm                                   category              2    0.000571
# Census_IsPenCapable                      category              2    0.000571
# Census_IsSecureBootEnabled               category              2    0.000571
# Census_IsTouchEnabled                    category              2    0.000571
# Census_IsVirtualDevice                   category              2    0.000571
# Wdft_IsGamer                             category              2    0.000571
# Census_IsAlwaysOnAlwaysConnectedCapable  category              2    0.000571
# HasDetections                            category              2    0.000571
# IsBeta                                   category              1    0.000286
#
#                                           null_pct  high_cardinality
# Census_OEMModelIdentifier                 1.150000              True
# Census_FirmwareVersionIdentifier          1.812857              True
# AVProductStatesIdentifier                 0.386000              True
# Census_ProcessorModelIdentifier           0.469143              True
# Census_OEMNameIdentifier                  1.068571              True
# Census_FirmwareManufacturerIdentifier     2.072571              True
# GeoNameIdentifier                         0.003714              True
# LocaleEnglishNameIdentifier               0.000000              True
# CountryIdentifier                         0.000000              True
# IeVerIdentifier                           0.637714              True
# AppVersion                                0.000000             False
# Census_OSUILocaleIdentifier               0.000000             False
# Census_OSBuildNumber                      0.000000             False
# EngineVersion                             0.000000             False
# OsBuild                                   0.000000             False
# OrganizationIdentifier                   30.939429             False
# Census_OSInstallLanguageIdentifier        0.667143             False
# Census_ChassisTypeName                    0.008000             False
# Census_ProcessorCoreCount                 0.468571             False
# Census_OSEdition                          0.000000             False
# Census_OSSkuName                          0.000000             False
# OsVer                                     0.000000             False
# Wdft_RegionIdentifier                     3.414000             False
# Census_OSBranch                           0.000000             False
# SmartScreen                              35.758000             False
# Census_MDC2FormFactor                     0.000000             False
# Census_OSInstallTypeName                  0.000000             False
# OsPlatformSubRelease                      0.000000             False
# OsSuite                                   0.000000             False
# Census_PowerPlatformRoleName              0.000000             False
# SkuEdition                                0.000000             False
# RtpStateBitfield                          0.368571             False
# Census_FlightRing                         0.000000             False
# Census_ActivationChannel                  0.000000             False
# Census_OSWUAutoUpdateOptionsName          0.000000             False
# UacLuaenable                              0.123143             False
# AVProductsEnabled                         0.386000             False
# AVProductsInstalled                       0.386000             False
# Platform                                  0.000000             False
# Census_ProcessorManufacturerIdentifier    0.468571             False
# Census_PrimaryDiskTypeName                0.142286             False
# Census_GenuineStateName                   0.000000             False
# Census_DeviceFamily                       0.000000             False
# Processor                                 0.000000             False
# Census_OSArchitecture                     0.000000             False
# Census_HasOpticalDiskDrive                0.000000             False
# ProductName                               0.000000             False
# IsSxsPassiveMode                          0.000000             False
# SMode                                     5.974286             False
# IsProtected                               0.384286             False
# Firewall                                  1.032857             False
# HasTpm                                    0.000000             False
# Census_IsPenCapable                       0.000000             False
# Census_IsSecureBootEnabled                0.000000             False
# Census_IsTouchEnabled                     0.000000             False
# Census_IsVirtualDevice                    0.181714             False
# Wdft_IsGamer                              3.414000             False
# Census_IsAlwaysOnAlwaysConnectedCapable   0.804000             False
# HasDetections                             0.000000             False
# IsBeta                                    0.000000             False

# %%
inspector1.numeric_summary()
# Out:
#                                                      dtype  unique_values  \
# Census_SystemVolumeTotalCapacity                   float64         112810
# Census_InternalBatteryNumberOfCharges              float64           4031
# Census_PrimaryDiskTotalCapacity                    float64            906
# Census_InternalPrimaryDiagonalDisplaySizeInInches  float64            483
# Census_TotalPhysicalRAM                            float64            449
# Census_InternalPrimaryDisplayResolutionVertical    float64            420
# Census_InternalPrimaryDisplayResolutionHorizontal  float64            374
# Census_OSBuildRevision                               int64            237
#
#                                                    pct_unique  null_pct  \
# Census_SystemVolumeTotalCapacity                    32.231429  0.595143
# Census_InternalBatteryNumberOfCharges                1.151714  3.003143
# Census_PrimaryDiskTotalCapacity                      0.258857  0.595143
# Census_InternalPrimaryDiagonalDisplaySizeInInches    0.138000  0.534000
# Census_TotalPhysicalRAM                              0.128286  0.896857
# Census_InternalPrimaryDisplayResolutionVertical      0.120000  0.533429
# Census_InternalPrimaryDisplayResolutionHorizontal    0.106857  0.533429
# Census_OSBuildRevision                               0.067714  0.000000
#
#                                                        min           max  \
# Census_SystemVolumeTotalCapacity                    9689.0  2.859558e+07
# Census_InternalBatteryNumberOfCharges                  0.0  4.294967e+09
# Census_PrimaryDiskTotalCapacity                    10240.0  2.859591e+07
# Census_InternalPrimaryDiagonalDisplaySizeInInches      4.9  1.420000e+02
# Census_TotalPhysicalRAM                              512.0  3.932160e+05
# Census_InternalPrimaryDisplayResolutionVertical       -1.0  4.320000e+03
# Census_InternalPrimaryDisplayResolutionHorizontal     -1.0  1.152000e+04
# Census_OSBuildRevision                                 0.0  1.906900e+04
#
#                                                    possible_id  \
# Census_SystemVolumeTotalCapacity                         False
# Census_InternalBatteryNumberOfCharges                    False
# Census_PrimaryDiskTotalCapacity                          False
# Census_InternalPrimaryDiagonalDisplaySizeInInches        False
# Census_TotalPhysicalRAM                                  False
# Census_InternalPrimaryDisplayResolutionVertical          False
# Census_InternalPrimaryDisplayResolutionHorizontal        False
# Census_OSBuildRevision                                   False
#
#                                                    likely_categorical
# Census_SystemVolumeTotalCapacity                                False
# Census_InternalBatteryNumberOfCharges                           False
# Census_PrimaryDiskTotalCapacity                                 False
# Census_InternalPrimaryDiagonalDisplaySizeInInches               False
# Census_TotalPhysicalRAM                                         False
# Census_InternalPrimaryDisplayResolutionVertical                 False
# Census_InternalPrimaryDisplayResolutionHorizontal               False
# Census_OSBuildRevision                                          False

# %%
preprocessor.fit_transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[304], line 1
# ----> 1 preprocessor.fit_transform(X_train)
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\compose\_column_transformer.py:999, in ColumnTransformer.fit_transform(self, X, y, **params)
#     996 else:
#     997     routed_params = self._get_empty_routing()
# --> 999 result = self._call_func_on_transformers(
#    1000     X,
#    1001     y,
#    1002     _fit_transform_one,
#    1003     column_as_labels=False,
#    1004     routed_params=routed_params,
#    1005 )
#    1007 if not result:
#    1008     self._update_fitted_transformers([])
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\compose\_column_transformer.py:901, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     889             extra_args = {}
#     890         jobs.append(
#     891             delayed(func)(
#     892                 transformer=clone(trans) if not fitted else trans,
#    (...)    898             )
#     899         )
# --> 901     return Parallel(n_jobs=self.n_jobs)(jobs)
#     903 except ValueError as e:
#     904     if "Expected 2D array, got 1D array instead" in str(e):
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\pipeline.py:1484, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1482 with _print_elapsed_time(message_clsname, message):
#    1483     if hasattr(transformer, "fit_transform"):
# -> 1484         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1485     else:
#    1486         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1487             X, **params.get("transform", {})
#    1488         )
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\pipeline.py:677, in Pipeline.fit_transform(self, X, y, **params)
#     638 """Fit the model and transform with the final estimator.
#     639
#     640 Fit all the transformers one after the other and sequentially transform
#    (...)    674     Transformed samples.
#     675 """
#     676 routed_params = self._check_method_params(method="fit_transform", props=params)
# --> 677 Xt = self._fit(X, y, routed_params)
#     679 last_step = self._final_estimator
#     680 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\pipeline.py:547, in Pipeline._fit(self, X, y, routed_params, raw_params)
#     540 # Fit or load from cache the current transformer
#     541 step_params = self._get_metadata_for_step(
#     542     step_idx=step_idx,
#     543     step_params=routed_params[name],
#     544     all_params=raw_params,
#     545 )
# --> 547 X, fitted_transformer = fit_transform_one_cached(
#     548     cloned_transformer,
#     549     X,
#     550     y,
#     551     weight=None,
#     552     message_clsname="Pipeline",
#     553     message=self._log_message(step_idx),
#     554     params=step_params,
#     555 )
#     556 # Replace the transformer of the step with the fitted
#     557 # transformer. This is necessary when loading the transformer
#     558 # from the cache.
#     559 self.steps[step_idx] = (name, fitted_transformer)
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\joblib\memory.py:326, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     325 def __call__(self, *args, **kwargs):
# --> 326     return self.func(*args, **kwargs)
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\pipeline.py:1484, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1482 with _print_elapsed_time(message_clsname, message):
#    1483     if hasattr(transformer, "fit_transform"):
# -> 1484         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1485     else:
#    1486         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1487             X, **params.get("transform", {})
#    1488         )
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:907, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     892         warnings.warn(
#     893             (
#     894                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)    902             UserWarning,
#     903         )
#     905 if y is None:
#     906     # fit method of arity 1 (unsupervised transformation)
# --> 907     return self.fit(X, **fit_params).transform(X)
#     908 else:
#     909     # fit method of arity 2 (supervised transformation)
#     910     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\impute\_base.py:447, in SimpleImputer.fit(self, X, y)
#     429 @_fit_context(prefer_skip_nested_validation=True)
#     430 def fit(self, X, y=None):
#     431     """Fit the imputer on `X`.
#     432
#     433     Parameters
#    (...)    445         Fitted estimator.
#     446     """
# --> 447     X = self._validate_input(X, in_fit=True)
#     449     # default fill_value is 0 for numerical input and "missing_value"
#     450     # otherwise
#     451     if self.fill_value is None:
#
# File c:\Users\JGarcia94\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\impute\_base.py:425, in SimpleImputer._validate_input(self, X, in_fit)
#     423     # Make sure we can safely cast fill_value dtype to the input data dtype
#     424     if not np.can_cast(fill_value_dtype, X.dtype, casting="same_kind"):
# --> 425         raise ValueError(err_msg)
#     427 return X
#
# ValueError: fill_value='Missing' (of type <class 'str'>) cannot be cast to the input data that is dtype('float64'). If fill_value is a Python scalar, instead pass  a numpy scalar (e.g. fill_value=np.uint8(0) if your data is of type np.uint8). Make sure that both dtypes are of the same kind.

# %% [markdown]
# ### 5.3. First Model Training

# %%
DecisionTree_pipe = Pipeline([

    ("preprocessing", preprocessor),

    ("model", DecisionTreeClassifier(
        max_depth=10,     # prevent overfitting
        #min_samples_leaf=50,
        #class_weight={0:1, 1:3}, #para darle más peso a los falsos negativos, default is 'balanced'
        random_state=42
    ))
])

# %%
DecisionTree_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(n_jobs=1,
#                                    transformers=[('num',
#                                                   ColumnTransformer(transformers=[('median',
#                                                                                    SimpleImputer(strategy='median'),
#                                                                                    ['Census_PrimaryDiskTotalCapacity',
#                                                                                     'Census_SystemVolumeTotalCapacity',
#                                                                                     'Census_TotalPhysicalRAM',
#                                                                                     'Census_InternalPrimaryDiagonalDisplaySizeInInches',
#                                                                                     'Census_InternalPrimaryDisplayResolutionHorizo...
#                                                    'AVProductStatesIdentifier',
#                                                    'CountryIdentifier',
#                                                    'CityIdentifier',
#                                                    'GeoNameIdentifier',
#                                                    'LocaleEnglishNameIdentifier',
#                                                    'IeVerIdentifier',
#                                                    'Census_OEMNameIdentifier',
#                                                    'Census_OEMModelIdentifier',
#                                                    'Census_ProcessorModelIdentifier',
#                                                    'Census_FirmwareManufacturerIdentifier',
#                                                    'Census_FirmwareVersionIdentifier'])])),
#                 ('model',
#                  DecisionTreeClassifier(max_depth=10, random_state=42))])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, fbeta_score, ConfusionMatrixDisplay

y_pred = DecisionTree_pipe.predict(X_test)

acc_dt = accuracy_score(y_test, y_pred)
f1_dt  = f1_score(y_test, y_pred)
f2_dt = fbeta_score(y_test, y_pred, beta=2) # Beta=2 para darle más peso a los falsos negativos
cm_dt  = confusion_matrix(y_test, y_pred)


print("=== Decision Tree — Validación ===\n")
print(f"Accuracy : {acc_dt:.4f}")
print(f"F1 Score : {f1_dt:.4f}")
print(f"F2 Score : {f2_dt:.4f}")

print(f"\nVerdaderos Negativos  (TN): {cm_dt[0,0]:,}")
print(f"Falsos Positivos      (FP): {cm_dt[0,1]:,}")
print(f"Escapes               (FN): {cm_dt[1,0]:,}")
print(f"Virus Cazados         (TP): {cm_dt[1,1]:,}")

fig, ax = plt.subplots(figsize=(5, 4))
ConfusionMatrixDisplay(confusion_matrix=cm_dt, display_labels=['Sin malware (0)', 'Con malware (1)']).plot(ax=ax, colorbar=False, cmap='Blues')
ax.set_title('Confusion Matrix — Decision Tree')
plt.tight_layout()
plt.show()
# Out:
# === Decision Tree — Validación ===
#
# Accuracy : 0.6255
# F1 Score : 0.6229
# F2 Score : 0.6203
#
# Verdaderos Negativos  (TN): 23,722
# Falsos Positivos      (FP): 13,785
# Escapes               (FN): 14,300
# Virus Cazados         (TP): 23,193

# %%
# Feature importance del Decision Tree tuneado
# Con OHE, los nombres de columnas los obtenemos del preprocessor
X_train_trans = DecisionTree_pipe.named_steps["preprocessing"].transform(X_train)
feature_names_dt = X_train_trans.columns.tolist()

fi_dt = pd.Series(
    DecisionTree_pipe.named_steps["model"].feature_importances_,
    index=feature_names_dt
).sort_values(ascending=False)
fi_dt_df = fi_dt.reset_index()
fi_dt_df.columns = ['feature', 'importance']

print("=== Top 20 features — Decision Tree ===\n")
print(fi_dt_df.head(20).to_string(index=False))

# Plot
top_n = 20
fi_dt_top = fi_dt_df.head(top_n)

fig, ax = plt.subplots(figsize=(8, 6))
ax.barh(fi_dt_top['feature'][::-1], fi_dt_top['importance'][::-1], color='steelblue')
ax.set_xlabel('Importancia')
ax.set_title(f'Top {top_n} features — Decision Tree')
plt.tight_layout()
plt.show()
# Out:
# === Top 20 features — Decision Tree ===
#
#                                                        feature  importance
#                              low_cat__SmartScreen_ExistsNotSet    0.395267
#                            high_cat__AVProductStatesIdentifier    0.230907
#                   num__median__Census_PrimaryDiskTotalCapacity    0.059559
#                                      low_cat__Wdft_IsGamer_1.0    0.033615
#                                         high_cat__AvSigVersion    0.031897
#                             low_cat__EngineVersion_1.1.15100.1    0.027730
#                           num__median__Census_TotalPhysicalRAM    0.018462
# num__median__Census_InternalPrimaryDiagonalDisplaySizeInInches    0.015926
#                            low_cat__AppVersion_4.18.1807.18075    0.010485
#                   low_cat__Census_OSInstallTypeName_UUPUpgrade    0.010312
#                                    high_cat__CountryIdentifier    0.009264
#                       low_cat__Census_OSUILocaleIdentifier_125    0.008632
#                                     high_cat__Census_OSVersion    0.008289
#                          low_cat__Census_IsVirtualDevice_Other    0.007368
#                            num__median__Census_OSBuildRevision    0.006503
#                                           high_cat__OsBuildLab    0.006455
#                             low_cat__EngineVersion_1.1.15200.1    0.006005
#                  num__median__Census_SystemVolumeTotalCapacity    0.005776
#                                         low_cat__SMode_Missing    0.005649
#                                         low_cat__Processor_x86    0.005532

# %% [markdown]
# ### 5.4. Threshold curve

# %%
y_prob = DecisionTree_pipe.predict_proba(X_test)[:,1]

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_test, y_prob)

# %%
plt.figure(figsize=(6,4))
plt.plot(thresholds, precision[:-1], label="Precision")
plt.plot(thresholds, recall[:-1], label="Recall")

plt.xlabel("Threshold")
plt.ylabel("Score")
plt.title("Precision / Recall vs Threshold")
plt.legend()
plt.show()

# %%
# Ajuste del umbral de clasificacion para reducir FN
# Criterio: minimizar FN (prioridad de negocio en detección de malware)
y_proba_dt = DecisionTree_pipe.predict_proba(X_test)[:, 1]

print(f"{'Threshold':<12} {'Accuracy':>10} {'F1':>10} {'F2':>10} {'FN':>10} {'FP':>10}")
print("-" * 68)

for threshold in [0.6, 0.55, 0.5, 0.45, 0.4, 0.35, 0.3, 0.25]:
    y_pred_t = (y_proba_dt >= threshold).astype(int)
    cm_t = confusion_matrix(y_val, y_pred_t)
    f1_t = f1_score(y_val, y_pred_t)
    f2_dt = fbeta_score(y_val, y_pred_t, beta=2)
    print(f"{threshold:<12} {accuracy_score(y_val, y_pred_t):>10.4f} {f1_t:>10.4f} {f2_dt:>10.4f} {cm_t[1,0]:>10,} {cm_t[0,1]:>10,}")

# Threshold elegido: 0.3 — minimiza FN (dispositivos infectados no detectados)
# En seguridad, un FN es más costoso que un FP
best_threshold_dt = 0.3
#print(f"\nThreshold seleccionado: {best_threshold_dt} (criterio: minimizar FN)")
# Out:
# Threshold      Accuracy         F1         F2         FN         FP
# --------------------------------------------------------------------
# 0.6              0.4987     0.3256     0.2697     28,418      9,182
# 0.55             0.4988     0.3953     0.3517     25,208     12,383
# 0.5              0.4998     0.4967     0.4950     18,980     18,532
# 0.45             0.4993     0.5457     0.5778     14,942     22,613
# 0.4              0.4989     0.5937     0.6698     10,037     27,543
# 0.35             0.4997     0.6093     0.7017      8,230     29,291
# 0.3              0.5003     0.6372     0.7626      4,583     32,897
# 0.25             0.5002     0.6511     0.7951      2,526     34,957

# %%
fi_dt_df.shape
# Out:
# (294, 2)

# %%
least_used_features = fi_dt[fi_dt == 0].index.tolist()

print(f"Number of unused features: {len(least_used_features)}")
# Out:
# Number of unused features: 190

# %%
low_importance_features = fi_dt[fi_dt < 0.001].index.tolist()

print(f"Low importance features: {len(low_importance_features)}")
# Out:
# Low importance features: 249

# %%
unused = fi_dt[fi_dt == 0]

print(f"{len(unused)} unused features")
# Out:
# 190 unused features

# %% [markdown]
# ### 5.5. Tuning de hiperparámetros — Decision Tree

# %%
from sklearn.model_selection import RandomizedSearchCV

# Submuestra para acelerar el tuning
sample_idx_dt = np.random.RandomState(42).choice(len(X_train), size=50_000, replace=False)
X_tune_dt = X_train.iloc[sample_idx_dt]
y_tune_dt  = y_train.iloc[sample_idx_dt]

param_dist_dt = {
    'model__criterion'        : ['gini', 'entropy'],
    'model__max_depth'        : [5, 10, 15, 20, None],
    'model__min_samples_split': [2, 10, 50],
    'model__min_samples_leaf' : [1, 5, 20],
    'model__max_features'     : [None, 'sqrt', 'log2'],
    'model__class_weight'     : ['balanced', None],
    'model__ccp_alpha'        : [0.0, 1e-4, 1e-3],
}

basic_dt_pipe = Pipeline([
    ("preprocessing", preprocessor),
    ("model", DecisionTreeClassifier(random_state=42))
])

dt_search = RandomizedSearchCV(
    estimator           = basic_dt_pipe,
    param_distributions = param_dist_dt,
    n_iter              = 30,
    scoring             = 'f1',
    cv                  = 3,
    random_state        = 42,
    n_jobs              = -1,
    verbose             = 1,
)
dt_search.fit(X_tune_dt, y_tune_dt)

print(f"Mejores parámetros: {dt_search.best_params_}")
print(f"Mejor F1 (CV):      {dt_search.best_score_:.4f}")

# Tuning del Decision Tree sobre datos que ya incluyen las 3 features de FE:
# av_enabled_ratio, screen_resolution, app_version_major.
# Se usa una submuestra de 50k filas para reducir el tiempo de búsqueda
# manteniendo representatividad (≈15% del train).
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# Mejores parámetros: {'model__min_samples_split': 10, 'model__min_samples_leaf': 5, 'model__max_features': None, 'model__max_depth': 20, 'model__criterion': 'gini', 'model__class_weight': 'balanced', 'model__ccp_alpha': 0.001}
# Mejor F1 (CV):      0.6520

# %%
# Reentrenamos con los mejores parámetros sobre todo el train transformado
best_dt_pipe = dt_search.best_estimator_

y_pred_best_dt = best_dt_pipe.predict(X_test)

acc_dt_tuned = accuracy_score(y_test, y_pred_best_dt)
f1_dt_tuned  = f1_score(y_test, y_pred_best_dt)
f2_dt_tuned  = fbeta_score(y_test, y_pred_best_dt, beta=2)
cm_dt_tuned  = confusion_matrix(y_test, y_pred_best_dt)

thresholds = np.linspace(0, 1, 101)
probs = best_dt_pipe.predict_proba(X_test)[:, 1]

f1_scores = [f1_score(y_test, probs > t) for t in thresholds]
f2_scores = [fbeta_score(y_test, probs > t, beta=2) for t in thresholds]

best_f1_idx = np.argmax(f1_scores)
best_f2_idx = np.argmax(f2_scores)

best_threshold_f1 = thresholds[best_f1_idx]
best_threshold_f2 = thresholds[best_f2_idx]

print("Best F1 threshold:", best_threshold_f1)
print("Best F2 threshold:", best_threshold_f2)

print("=== Decision Tree Tuneado - Validacion ===")
print()
print(f"Accuracy : {acc_dt_tuned:.4f}")
print(f"F1 Score : {f1_dt_tuned:.4f}")
print(f"F2 Score : {f2_dt_tuned:.4f}")
print(f"\nVerdaderos Negativos  (TN): {cm_dt_tuned[0,0]:,}")
print(f"Falsos Positivos      (FP): {cm_dt_tuned[0,1]:,}")
print(f"Falsos Negativos      (FN): {cm_dt_tuned[1,0]:,}")
print(f"Verdaderos Positivos  (TP): {cm_dt_tuned[1,1]:,}")
# Out:
# Best F1 threshold: 0.0
# Best F2 threshold: 0.0
# === Decision Tree Tuneado - Validacion ===
#
# Accuracy : 0.6096
# F1 Score : 0.6464
# F2 Score : 0.6853
#
# Verdaderos Negativos  (TN): 18,949
# Falsos Positivos      (FP): 18,558
# Falsos Negativos      (FN): 10,724
# Verdaderos Positivos  (TP): 26,769

# %%
# Feature importance del Decision Tree tuneado
# Con OHE, los nombres de columnas los obtenemos del preprocessor
X_train_trans = best_dt_pipe.named_steps["preprocessing"].transform(X_train)
feature_names_dt = X_train_trans.columns.tolist()

fi_best_dt = pd.Series(
    best_dt_pipe.named_steps["model"].feature_importances_,
    index=feature_names_dt
).sort_values(ascending=False)
fi_best_dt_df = fi_best_dt.reset_index()
fi_best_dt_df.columns = ['feature', 'importance']

print("=== Top 20 features — Decision Tree ===\n")
print(fi_best_dt_df.head(20).to_string(index=False))

# Plot
top_n = 20
fi_best_dt_top = fi_best_dt_df.head(top_n)

fig, ax = plt.subplots(figsize=(8, 6))
ax.barh(fi_best_dt_top['feature'][::-1], fi_best_dt_top['importance'][::-1], color='steelblue')
ax.set_xlabel('Importancia')
ax.set_title(f'Top {top_n} features — Decision Tree')
plt.tight_layout()
plt.show()
# Out:
# === Top 20 features — Decision Tree ===
#
#                                                        feature  importance
#                              low_cat__SmartScreen_ExistsNotSet    0.584498
#                            high_cat__AVProductStatesIdentifier    0.270109
#                   num__median__Census_PrimaryDiskTotalCapacity    0.069891
#                                      low_cat__Wdft_IsGamer_1.0    0.048390
#                                         high_cat__AvSigVersion    0.027111
#                     high_cat__Census_FirmwareVersionIdentifier    0.000000
#                             low_cat__Census_FlightRing_NOT_SET    0.000000
#                               low_cat__Census_FlightRing_Other    0.000000
#                              low_cat__Census_FlightRing_Retail    0.000000
#                             low_cat__Census_FlightRing_Unknown    0.000000
#                                         low_cat__OsBuild_10240    0.000000
#                                         low_cat__OsBuild_10586    0.000000
#                                         low_cat__OsBuild_14393    0.000000
# num__median__Census_InternalPrimaryDisplayResolutionHorizontal    0.000000
#                                         low_cat__OsBuild_16299    0.000000
#                                         low_cat__OsBuild_17134    0.000000
#                                          low_cat__OsBuild_7601    0.000000
#                                          low_cat__OsBuild_9600    0.000000
#                                         low_cat__OsBuild_Other    0.000000
#                             low_cat__EngineVersion_1.1.14104.0    0.000000

# %%
# Ajuste del umbral de clasificacion para reducir FN
# Criterio: minimizar FN (prioridad de negocio en detección de malware)
y_proba_best_dt = best_dt_pipe.predict_proba(X_test)[:, 1]

print(f"{'Threshold':<12} {'Accuracy':>10} {'F1':>10} {'F2':>10} {'FN':>10} {'FP':>10}")
print("-" * 68)

for threshold in [0.6, 0.55, 0.5, 0.45, 0.4, 0.35, 0.3, 0.25]:
    y_pred_t = (y_proba_best_dt >= threshold).astype(int)
    cm_t = confusion_matrix(y_test, y_pred_t)
    f1_t = f1_score(y_test, y_pred_t)
    f2_dt = fbeta_score(y_test, y_pred_t, beta=2)
    print(f"{threshold:<12} {accuracy_score(y_test, y_pred_t):>10.4f} {f1_t:>10.4f} {f2_dt:>10.4f} {cm_t[1,0]:>10,} {cm_t[0,1]:>10,}")

# Threshold elegido: 0.3 — minimiza FN (dispositivos infectados no detectados)
# En seguridad, un FN es más costoso que un FP
best_threshold_dt = 0.3
#print(f"\nThreshold seleccionado: {best_threshold_dt} (criterio: minimizar FN)")
# Out:
# Threshold      Accuracy         F1         F2         FN         FP
# -------------------------------------------------------
# 0.6              0.5998     0.4784     0.4049     23,725      6,292
# 0.55             0.5998     0.4784     0.4049     23,725      6,292
# 0.5              0.6096     0.6464     0.6853     10,724     18,558
# 0.45             0.6096     0.6464     0.6853     10,724     18,558
# 0.4              0.6096     0.6464     0.6853     10,724     18,558
# 0.35             0.4999     0.6666     0.8333          0     37,507
# 0.3              0.4999     0.6666     0.8333          0     37,507
# 0.25             0.4999     0.6666     0.8333          0     37,507

# %% [markdown]
# ## 6. Otros modelos

# %% [markdown]
# ### 6.1. Random Forest

# %% [markdown]
# #### First Model

# %%
Random_Forest_model_pipeline = Pipeline([
    
    ("preprocessing", preprocessor),
    
    ("model", RandomForestClassifier(
        n_estimators=200,
        max_depth=None,
        n_jobs=-1,
        random_state=42
    ))
])

# %%
Random_Forest_model_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(n_jobs=1,
#                                    transformers=[('num',
#                                                   ColumnTransformer(transformers=[('median',
#                                                                                    SimpleImputer(strategy='median'),
#                                                                                    ['Census_PrimaryDiskTotalCapacity',
#                                                                                     'Census_SystemVolumeTotalCapacity',
#                                                                                     'Census_TotalPhysicalRAM',
#                                                                                     'Census_InternalPrimaryDiagonalDisplaySizeInInches',
#                                                                                     'Census_InternalPrimaryDisplayResolutionHorizo...
#                                                    'CountryIdentifier',
#                                                    'CityIdentifier',
#                                                    'GeoNameIdentifier',
#                                                    'LocaleEnglishNameIdentifier',
#                                                    'IeVerIdentifier',
#                                                    'Census_OEMNameIdentifier',
#                                                    'Census_OEMModelIdentifier',
#                                                    'Census_ProcessorModelIdentifier',
#                                                    'Census_FirmwareManufacturerIdentifier',
#                                                    'Census_FirmwareVersionIdentifier'])])),
#                 ('model',
#                  RandomForestClassifier(n_estimators=200, n_jobs=-1,
#                                         random_state=42))])

# %% [markdown]
# #### Tuning Hyperparámetros Random Forest

# %%
from sklearn.model_selection import RandomizedSearchCV

# Submuestra reducida para acelerar el tuning
sample_idx = np.random.RandomState(42).choice(len(X_train), size=50_000, replace=False)
X_tune = X_train.iloc[sample_idx]
y_tune = y_train.iloc[sample_idx]

param_dist = {
    "model__n_estimators"     : [100, 200],
    "model__max_depth"        : [10, 20, None],
    "model__min_samples_split": [2, 10],
    "model__min_samples_leaf" : [1, 4],
    "model__max_features"     : ['sqrt', 'log2'],
    "model__class_weight"     : [None, 'balanced'],
}

rf_pipe = Pipeline([
    ("preprocessing", preprocessor),
    ("model", RandomForestClassifier(random_state=42, n_jobs=-1))
])

rf_search = RandomizedSearchCV(
    estimator           = rf_pipe,
    param_distributions = param_dist,
    n_iter              = 10,
    scoring             = 'recall',
    cv                  = 2,
    random_state        = 42,
    verbose             = 2,
    n_jobs              = -1,
)

rf_search.fit(X_tune, y_tune)

print(f"\nMejores parámetros: {rf_search.best_params_}")
print(f"Mejor recall (CV) : {rf_search.best_score_:.4f}")
# Out:
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
#
# Mejores parámetros: {'model__n_estimators': 100, 'model__min_samples_split': 2, 'model__min_samples_leaf': 1, 'model__max_features': 'sqrt', 'model__max_depth': 10, 'model__class_weight': None}
# Mejor recall (CV) : 0.6778

# %% [markdown]
# #### Feature Importance

# %%
# Con OHE, los nombres reales de columnas los da el preprocessor
feature_names = preprocessor.get_feature_names_out().tolist()

importances = best_rf.feature_importances_
fi_df = pd.DataFrame({
    'feature'   : feature_names,
    'importance': importances
}).sort_values('importance', ascending=False).reset_index(drop=True)

print(fi_df.head(20).to_string(index=False))
# Out:
#                                                feature  importance
#                      cat_low__SmartScreen_Existsnotset    0.263830
#                         num__AVProductStatesIdentifier    0.084657
#                               num__AVProductsInstalled    0.076897
#                                  num__av_enabled_ratio    0.062321
#                      cat_low__SmartScreen_Requireadmin    0.048349
#                                            cat_high__9    0.047993
#                           num__Census_TotalPhysicalRAM    0.024354
#                                            cat_high__7    0.024093
#                           cat_low__SmartScreen_Missing    0.021835
# num__Census_InternalPrimaryDiagonalDisplaySizeInInches    0.018546
#                   num__Census_PrimaryDiskTotalCapacity    0.018478
#                  num__Census_SystemVolumeTotalCapacity    0.015734
#                                      num__Wdft_IsGamer    0.012180
#                   num__Census_ProcessorModelIdentifier    0.012022
#                                            cat_high__6    0.009940
#                                       num__IsProtected    0.009857
#                         num__Census_ProcessorCoreCount    0.009438
#                            num__Census_OSBuildRevision    0.007850
#                   cat_low__Census_OSArchitecture_amd64    0.007769
#           cat_low__Census_OSInstallTypeName_UUPUpgrade    0.007722

# %%
# Plot top 20 features
top_n = 20
fi_top = fi_df.head(top_n)

fig, ax = plt.subplots(figsize=(10, 7))
ax.barh(fi_top['feature'][::-1], fi_top['importance'][::-1], color='steelblue')
ax.set_xlabel('Importancia')
ax.set_title(f'Top {top_n} features más importantes (RF tuneado)')
plt.tight_layout()
plt.show()

# Features con importancia casi nula (candidatas a eliminar)
threshold = 0.001
low_importance = fi_df[fi_df['importance'] < threshold]
print(f"\nFeatures con importancia < {threshold}: {len(low_importance)}")
print(low_importance['feature'].tolist())
# Out:
# Features con importancia < 0.001: 82
# ['cat_low__Census_OSInstallTypeName_Reset', 'num__Census_IsSecureBootEnabled', 'cat_low__OsPlatformSubRelease_rs3', 'cat_low__Census_GenuineStateName_OFFLINE', 'cat_low__Census_PrimaryDiskTypeName_UNKNOWN', 'cat_low__SkuEdition_Home', 'cat_low__SmartScreen_Off', 'num__OsSuite', 'cat_low__Census_PowerPlatformRoleName_Mobile', 'cat_low__Census_OSInstallTypeName_Refresh', 'cat_low__Census_GenuineStateName_INVALID_LICENSE', 'cat_low__Census_OSInstallTypeName_Other', 'cat_low__SkuEdition_Pro', 'num__HasTpm', 'cat_low__Platform_windows10', 'cat_low__OsPlatformSubRelease_windows7', 'cat_low__SmartScreen_Warn', 'cat_high__15', 'cat_low__OsPlatformSubRelease_rs1', 'cat_low__Census_OSInstallTypeName_Upgrade', 'cat_low__Census_ProcessorManufacturerIdentifier_5.0', 'cat_low__OsPlatformSubRelease_th2', 'cat_low__Census_FlightRing_Retail', 'cat_low__Census_FlightRing_NOT_SET', 'cat_low__OsPlatformSubRelease_th1', 'cat_low__OsPlatformSubRelease_rs2', 'cat_low__ProductName_mse', 'cat_low__Census_PrimaryDiskTypeName_Unspecified', 'cat_low__Platform_windows8', 'cat_low__ProductName_win8defender', 'cat_low__Census_ActivationChannel_OEM:NONSLP', 'num__Census_IsPenCapable', 'cat_low__Census_ProcessorManufacturerIdentifier_1.0', 'cat_low__OsPlatformSubRelease_windows8.1', 'cat_low__SkuEdition_Invalid', 'cat_low__Census_OSWUAutoUpdateOptionsName_AutoInstallAndRebootAtMaintenanceTime', 'cat_low__Census_FlightRing_Unknown', 'num__Firewall', 'cat_low__Platform_windows7', 'num__UacLuaenable', 'cat_low__Census_PowerPlatformRoleName_Workstation', 'cat_low__Census_OSInstallTypeName_CleanPCRefresh', 'cat_low__Census_OSInstallTypeName_Clean', 'cat_low__Census_OSWUAutoUpdateOptionsName_DownloadNotify', 'cat_low__Census_PowerPlatformRoleName_SOHOServer', 'cat_low__SkuEdition_Enterprise', 'cat_low__SkuEdition_Education', 'cat_low__SmartScreen_Prompt', 'cat_low__Census_GenuineStateName_UNKNOWN', 'cat_low__Census_ProcessorManufacturerIdentifier_Missing', 'cat_low__Platform_windows2016', 'cat_low__Census_PowerPlatformRoleName_UNKNOWN', 'cat_low__Census_ActivationChannel_Retail:TB:Eval', 'cat_low__OsPlatformSubRelease_prers5', 'cat_low__Census_OSWUAutoUpdateOptionsName_Off', 'cat_low__Census_PrimaryDiskTypeName_Missing', 'cat_low__Census_DeviceFamily_Windows.Server', 'cat_low__Census_PowerPlatformRoleName_AppliancePC', 'cat_low__Census_DeviceFamily_Windows.Desktop', 'cat_low__SmartScreen_Block', 'cat_low__Census_FlightRing_WIF', 'cat_low__Census_FlightRing_RP', 'cat_low__Census_FlightRing_WIS', 'cat_low__SkuEdition_Enterprise LTSB', 'cat_low__SkuEdition_Server', 'cat_low__Census_ActivationChannel_Volume:MAK', 'cat_low__Census_FlightRing_Disabled', 'cat_low__SkuEdition_Cloud', 'cat_low__Census_PowerPlatformRoleName_EnterpriseServer', 'num__Census_IsFlightsDisabled', 'cat_low__Census_ProcessorManufacturerIdentifier_10.0', 'cat_low__SmartScreen_On', 'num__IsBeta', 'cat_low__ProductName_mseprerelease', 'cat_low__Processor_arm64', 'cat_low__Census_DeviceFamily_Windows', 'cat_low__Census_OSArchitecture_arm64', 'cat_low__Census_ProcessorManufacturerIdentifier_3.0', 'cat_low__Census_PowerPlatformRoleName_PerformanceServer', 'cat_low__Census_PowerPlatformRoleName_Missing', 'num__app_version_major', 'cat_low__Census_FlightRing_OSG']

# %%
# Eliminamos features con baja importancia y sin señal real
cols_to_drop_fi = ['HasTpm', 'Firewall', 'ProductName', 'IsBeta', 'Census_IsFlightsDisabled', 'UacLuaenable']

X_clean2 = X_clean.drop(columns=cols_to_drop_fi)
print(f"Shape anterior: {X_clean.shape}")
print(f"Shape nuevo   : {X_clean2.shape}")

# Nuevo split
X_train2, X_temp2, y_train2, y_temp2 = train_test_split(X_clean2, y, test_size=0.30, random_state=42)
X_val2, X_test2, y_val2, y_test2     = train_test_split(X_temp2, y_temp2, test_size=0.50, random_state=42)

# Nuevas listas de columnas
num_cols2 = X_train2.select_dtypes(include='number').columns.tolist()
cat_cols2 = X_train2.select_dtypes(include='object').columns.tolist()

print(f"\nNuméricas: {len(num_cols2)}")
print(f"Categóricas: {len(cat_cols2)}")
# Out:
# Shape anterior: (500000, 67)
# Shape nuevo   : (500000, 61)
#
# Numéricas: 28
# Categóricas: 33

# %%
# Nuevo pipeline con las features reducidas
numeric_transformer2 = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
])

categorical_transformer2 = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='Missing')),
    ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)),
])

preprocessor2 = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer2, num_cols2),
        ('cat', categorical_transformer2, cat_cols2),
    ],
    remainder='drop'
)

# fit_transform en train, transform en val y test
X_train2_t = preprocessor2.fit_transform(X_train2, y_train2)
X_val2_t   = preprocessor2.transform(X_val2)
X_test2_t  = preprocessor2.transform(X_test2)

print(f"Train: {X_train2_t.shape}")
print(f"Val  : {X_val2_t.shape}")
print(f"Test : {X_test2_t.shape}")

# Reentrenamos con los mejores parámetros del tuning
best_rf2 = RandomForestClassifier(**rf_search.best_params_, random_state=42, n_jobs=-1)
best_rf2.fit(X_train2_t, y_train2)
print("\nEntrenamiento completado")
# Out:
# Train: (350000, 61)
# Val  : (75000, 61)
# Test : (75000, 61)
#
# Entrenamiento completado

# %%
# Evaluación del modelo con features reducidas
y_pred_val2 = best_rf2.predict(X_val2_t)

acc2 = accuracy_score(y_val2, y_pred_val2)
f1_2 = f1_score(y_val2, y_pred_val2)
f2_2 = fbeta_score(y_val2, y_pred_val2, beta=2)
cm2  = confusion_matrix(y_val2, y_pred_val2)

print("=== Comparativa final ===\n")
print(f"{'Modelo':<30} {'Accuracy':>10} {'F1':>10} {'F2':>10}")
print("-" * 62)
print(f"{'Dummy (baseline)':<30} {0.5002:>10.4f} {0.0000:>10.4f} {0.0000:>10.4f}")
print(f"{'RF base':<30} {0.6329:>10.4f} {0.6216:>10.4f} {f2:>10.4f}")
print(f"{'RF tuneado':<30} {0.6275:>10.4f} {0.6456:>10.4f} {f2_tuned:>10.4f}")
print(f"{'RF tuneado + feature sel.':<30} {acc2:>10.4f} {f1_2:>10.4f} {f2_2:>10.4f}")

print(f"\nVerdaderos Negativos  (TN): {cm2[0,0]:,}")
print(f"Falsos Positivos      (FP): {cm2[0,1]:,}")
print(f"Falsos Negativos      (FN): {cm2[1,0]:,}")
print(f"Verdaderos Positivos  (TP): {cm2[1,1]:,}")

fig, ax = plt.subplots(figsize=(5, 4))
ConfusionMatrixDisplay(confusion_matrix=cm2, display_labels=['Sin malware (0)', 'Con malware (1)']).plot(ax=ax, colorbar=False, cmap='Blues')
ax.set_title('Confusion Matrix — RF tuneado + feature selection')
plt.tight_layout()
plt.show()
# Out:
# === Comparativa final ===
#
# Modelo                           Accuracy         F1         F2
# --------------------------------------------------------------
# Dummy (baseline)                   0.5002     0.0000     0.0000
# RF base                            0.6329     0.6216     0.6124
# RF tuneado                         0.6275     0.6456     0.6602
# RF tuneado + feature sel.          0.6273     0.6436     0.6611
#
# Verdaderos Negativos  (TN): 21,806
# Falsos Positivos      (FP): 15,708
# Falsos Negativos      (FN): 12,248
# Verdaderos Positivos  (TP): 25,238

# %%
# Correlación de las nuevas features con el target (calculada sobre train)
new_features = ["av_enabled_ratio", "screen_resolution", "app_version_major"]
corr_new = pd.concat([X_train[new_features], y_train], axis=1).corr()["HasDetections"].drop("HasDetections")
print("Correlación nuevas features con HasDetections:")
print(corr_new.sort_values(ascending=False))
# Out:
# Correlación nuevas features con HasDetections:
# av_enabled_ratio     0.136651
# screen_resolution    0.017186
# app_version_major         NaN
# Name: HasDetections, dtype: float64

# %% [markdown]
# #### Evaluación final en Test

# %%
# Evaluación final — solo se ejecuta una vez con el mejor modelo (RF tuneado)
y_pred_test = best_rf.predict(X_test_transformed)

acc_test = accuracy_score(y_test, y_pred_test)
f1_test  = f1_score(y_test, y_pred_test)
f2_test  = fbeta_score(y_test, y_pred_test, beta=2)
cm_test  = confusion_matrix(y_test, y_pred_test)

print("=== Evaluación FINAL en Test ===\n")
print(f"Accuracy : {acc_test:.4f}")
print(f"F1 Score : {f1_test:.4f}")
print(f"F2 Score : {f2_test:.4f}")
print(f"\nVerdaderos Negativos  (TN): {cm_test[0,0]:,}")
print(f"Falsos Positivos      (FP): {cm_test[0,1]:,}")
print(f"Falsos Negativos      (FN): {cm_test[1,0]:,}")
print(f"Verdaderos Positivos  (TP): {cm_test[1,1]:,}")

fig, ax = plt.subplots(figsize=(5, 4))
ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=['Sin malware (0)', 'Con malware (1)']).plot(ax=ax, colorbar=False, cmap='Blues')
ax.set_title('Confusion Matrix — Evaluación Final (Test)')
plt.tight_layout()
plt.show()
# Out:
# === Evaluación FINAL en Test ===
#
# Accuracy : 0.6269
# F1 Score : 0.6452
# F2 Score : 0.6634
#
# Verdaderos Negativos  (TN): 21,584
# Falsos Positivos      (FP): 15,794
# Falsos Negativos      (FN): 12,185
# Verdaderos Positivos  (TP): 25,437

# %% [markdown]
# #### Exploración de max_depth

# %%
# Exploración de max_depth manteniendo el resto de parámetros del mejor modelo
best_params = rf_search.best_params_.copy()

print(f"{'max_depth':<12} {'Accuracy':>10} {'F1':>10} {'F2':>10} {'FN':>10}")
print("-" * 55)

for depth in [10, 15, 20, 25, None]:
    params = {**best_params, 'max_depth': depth}
    rf = RandomForestClassifier(**params, random_state=42, n_jobs=-1)
    rf.fit(X_train_transformed, y_train)
    y_pred = rf.predict(X_val_transformed)
    cm = confusion_matrix(y_val, y_pred)
    fn = cm[1, 0]
    print(f"{str(depth):<12} {accuracy_score(y_val, y_pred):>10.4f} {f1_score(y_val, y_pred):>10.4f} {fbeta_score(y_val, y_pred, beta=2):>10.4f} {fn:>10,}")
# Out:
# max_depth      Accuracy         F1         F2         FN
# -------------------------------------------------------
# 10               0.6260     0.6426     0.6602     12,277
# 15               0.6364     0.6446     0.6536     12,756
# 20               0.6424     0.6444     0.6467     13,184
# 25               0.6431     0.6413     0.6396     13,551
# None             0.6421     0.6332     0.6241     14,314

# %% [markdown]
# #### Threshold tuning

# %%
# Threshold tuning: ajustamos el umbral de clasificación para reducir FN
y_proba = best_rf.predict_proba(X_val_transformed)[:, 1]

print(f"{'Threshold':<12} {'Accuracy':>10} {'F1':>10} {'F2':>10} {'FN':>10} {'FP':>10}")
print("-" * 65)

for threshold in [0.5, 0.45, 0.4, 0.35, 0.3]:
    y_pred_t = (y_proba >= threshold).astype(int)
    cm = confusion_matrix(y_val, y_pred_t)
    print(f"{threshold:<12} {accuracy_score(y_val, y_pred_t):>10.4f} {f1_score(y_val, y_pred_t):>10.4f} {fbeta_score(y_val, y_pred_t, beta=2):>10.4f} {cm[1,0]:>10,} {cm[0,1]:>10,}")
# Out:
# Threshold      Accuracy         F1         F2         FN         FP
# -----------------------------------------------------------------
# 0.5              0.6260     0.6426     0.6602     12,277     15,770
# 0.45             0.6153     0.6712     0.7355      8,036     20,815
# 0.4              0.5937     0.6839     0.7892      4,519     25,954
# 0.35             0.5581     0.6816     0.8191      2,012     31,129
# 0.3              0.5191     0.6724     0.8316        468     35,597

# %% [markdown]
# #### Evaluación final en Test (threshold=0.45)

# %%
THRESHOLD = 0.45

# Probabilidades en test
y_proba_test = best_rf.predict_proba(X_test_transformed)[:, 1]
y_pred_test_t = (y_proba_test >= THRESHOLD).astype(int)

acc_final  = accuracy_score(y_test, y_pred_test_t)
f1_final   = f1_score(y_test, y_pred_test_t)
f2_final   = fbeta_score(y_test, y_pred_test_t, beta=2)
cm_final   = confusion_matrix(y_test, y_pred_test_t)

print(f"=== Evaluación FINAL en Test (threshold={THRESHOLD}) ===\n")
print(f"Accuracy : {acc_final:.4f}")
print(f"F1 Score : {f1_final:.4f}")
print(f"F2 Score : {f2_final:.4f}")
print(f"\nVerdaderos Negativos  (TN): {cm_final[0,0]:,}")
print(f"Falsos Positivos      (FP): {cm_final[0,1]:,}")
print(f"Falsos Negativos      (FN): {cm_final[1,0]:,}")
print(f"Verdaderos Positivos  (TP): {cm_final[1,1]:,}")

fig, ax = plt.subplots(figsize=(5, 4))
ConfusionMatrixDisplay(confusion_matrix=cm_final, display_labels=['Sin malware (0)', 'Con malware (1)']).plot(ax=ax, colorbar=False, cmap='Blues')
ax.set_title(f'Confusion Matrix — Test final (threshold={THRESHOLD})')
plt.tight_layout()
plt.show()

# Comparativa completa
print("\n=== Comparativa completa ===\n")
print(f"{'Modelo':<35} {'Accuracy':>10} {'F1':>10} {'F2':>10} {'FN':>10}")
print("-" * 78)
print(f"{'Dummy (baseline)':<35} {0.5002:>10.4f} {0.0000:>10.4f} {0.0000:>10.4f} {'—':>10}")
print(f"{'RF base (threshold=0.5)':<35} {0.6329:>10.4f} {0.6216:>10.4f} {f2:>10.4f} {14873:>10,}")
print(f"{'RF tuneado (threshold=0.5)':<35} {0.6275:>10.4f} {0.6456:>10.4f} {f2_tuned:>10.4f} {12038:>10,}")
print(f"{'RF tuneado + FE (threshold=0.45)':<35} {acc_final:>10.4f} {f1_final:>10.4f} {f2_final:>10.4f} {cm_final[1,0]:>10,}")
# Out:
# === Evaluación FINAL en Test (threshold=0.45) ===
#
# Accuracy : 0.6178
# F1 Score : 0.6749
# F2 Score : 0.7400
#
# Verdaderos Negativos  (TN): 16,582
# Falsos Positivos      (FP): 20,796
# Falsos Negativos      (FN): 7,870
# Verdaderos Positivos  (TP): 29,752
# === Comparativa completa ===
#
# Modelo                                Accuracy         F1         F2         FN
# ------------------------------------------------------------------------------
# Dummy (baseline)                        0.5002     0.0000     0.0000          —
# RF base (threshold=0.5)                 0.6329     0.6216     0.6124     14,873
# RF tuneado (threshold=0.5)              0.6275     0.6456     0.6602     12,038
# RF tuneado + FE (threshold=0.45)        0.6178     0.6749     0.7400      7,870

# %% [markdown]
# ### 6.2. LightGBM

# %%
import re

class CleanFeatureNames(BaseEstimator, TransformerMixin):

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X = pd.DataFrame(X).copy()

        X.columns = [
            re.sub(r"[^0-9a-zA-Z_]", "_", str(col))
            for col in X.columns
        ]

        return X

# %%
from lightgbm import LGBMClassifier

# Entrenamiento LightGBM con los mismos datos transformados
lgbm = LGBMClassifier(
    n_estimators=100,
    random_state=42,
    n_jobs=-1,
    verbosity=-1,
    categorical_feature=None   # force no categorical features
)

lgbm_pipe = Pipeline([
    ("preprocessing", preprocessor),
    ("clean_names", CleanFeatureNames()),
    ("model", lgbm)
])


lgbm_pipe.fit(X_train, y_train)

# Evaluación en validación con threshold=0.5
y_pred_lgbm = lgbm_pipe.predict(X_test)
acc_lgbm = accuracy_score(y_test, y_pred_lgbm)
f1_lgbm  = f1_score(y_test, y_pred_lgbm)
f2_lgbm  = fbeta_score(y_test, y_pred_lgbm, beta=2)
cm_lgbm  = confusion_matrix(y_test, y_pred_lgbm)

print("=== LightGBM (threshold=0.5) — Validación ===\n")
print(f"Accuracy : {acc_lgbm:.4f}")
print(f"F1 Score : {f1_lgbm:.4f}")
print(f"F2 Score : {f2_lgbm:.4f}")
print(f"FN       : {cm_lgbm[1,0]:,}")
print(f"FP       : {cm_lgbm[0,1]:,}")


# Feature importance de LightGBM


X_train_trans = lgbm_pipe.named_steps["clean_names"].transform(
    lgbm_pipe.named_steps["preprocessing"].transform(X_train)
)

feature_names = X_train_trans.columns

fi_lgbm = pd.Series(
    lgbm_pipe.named_steps["model"].feature_importances_,
    index=feature_names
).sort_values(ascending=False)


top_n = 20
fi_top = fi_lgbm.head(top_n)

fig, ax = plt.subplots(figsize=(8,6))

ax.barh(fi_top.index[::-1], fi_top.values[::-1])

for i, v in enumerate(fi_top.values[::-1]):
    ax.text(v, i, f"{v:.0f}", va="center")

ax.set_title(f"Top {top_n} features — LightGBM")
ax.set_xlabel("Importance")

plt.tight_layout()
plt.show()


# Comparativa con el mejor RF
# print("\n=== Comparativa ===\n")
# print(f"{'Modelo':<35} {'Accuracy':>10} {'F1':>10} {'F2':>10} {'FN':>10}")
# print("-" * 78)
# print(f"{'RF tuneado + FE (0.45)':<35} {0.6206:>10.4f} {0.6734:>10.4f} {f2_final:>10.4f} {8290:>10,}")
# print(f"{'LightGBM (0.5)':<35} {acc_lgbm:>10.4f} {f1_lgbm:>10.4f} {f2_lgbm:>10.4f} {cm_lgbm[1,0]:>10,}")
# Out:
# c:\Users\jonmi\AppData\Local\Programs\Python\Python313\Lib\site-packages\lightgbm\basic.py:2137: UserWarning: categorical_feature keyword has been found in `params` and will be ignored.
# Please use categorical_feature argument of the Dataset constructor to pass this parameter.
#   _log_warning(
# === LightGBM (threshold=0.5) — Validación ===
#
# Accuracy : 0.6491
# F1 Score : 0.6453
# F2 Score : 0.6413
# FN       : 13,550
# FP       : 12,771

# %%
X_train_trans = lgbm_pipe.named_steps["preprocessing"].transform(X_train)

#print(X_train_trans.columns)

Columnname = 'low_cat__SmartScreen_ExistsNotSet'
print(f"Importancia de '{Columnname}' en LightGBM: {fi_lgbm[Columnname]:.4f}")
# Out:
# Importancia de 'low_cat__SmartScreen_ExistsNotSet' en LightGBM: 71.0000

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# ### Tarea
# Clasificación para detectar malware en dispositivos Windows (`HasDetections`: 0 = sin malware, 1 = con malware). Dataset balanceado (~50% por clase, ~500 k dispositivos).
#
# ### Modelo principal: Decision Tree
#
# El Decision Tree tuneado es el modelo central de este trabajo. Tras optimizar sus hiperparámetros con `RandomizedSearchCV` y ajustar el umbral de clasificación, los resultados en validación son:
#
# | Modelo | Accuracy | F1 | F2 | FN | FP |
# |---|---|---|---|---|---|
# | DummyClassifier (baseline) | 0.5002 | 0.0000 | 0.0000 | — | — |
# | DT base (`max_depth=10`) | 0.6215 | 0.6411 | 0.6617 | 12,138 | — | — |
# | DT tuneado (`threshold=0.50`) | 0.6083 |  0.6280 | 0.6477 | 12,690 | 16,684 |
# | DT tuneado (`threshold=0.45`) | 0.6082 | 0.6344 | 0.6612 | 11,985 | 17,403 |
# | DT tuneado (`threshold=0.40`) | 0.5775 | 0.6782 | 0.7916 | 4,093 | 27,596 |
# | **DT en test (`threshold=0.30`)** | **0.5616** | **0.6798** | **0.8096** | **2,717** | **30,165** |
#
# ### Razonamiento de negocio: por qué threshold=0.30
#
# En detección de malware, **un Falso Negativo (FN) es mucho más costoso que un Falso Positivo (FP)**:
# - **FN**: un dispositivo infectado pasa desapercibido → el malware actúa sin restricciones, puede propagarse y robar datos.
# - **FP**: un dispositivo limpio recibe una alerta → el usuario revisa innecesariamente, pero no hay daño real.
#
# Bajar el threshold de 0.50 a **0.30** reduce los FN de 12,690 a **2,800** (−78%), con una pérdida de accuracy de solo 5 puntos. El F1 prácticamente no empeora (0.6280 → 0.6773) porque la ganancia en recall compensa la caída en precision. El F2 mejora de manera clara hasta un **0,8096**. Este trade-off es claramente favorable en un contexto de seguridad.
#
#
# ### Experimentación adicional
#
# Como extensión, se probaron Random Forest y LightGBM sobre los mismos datos transformados:
#
# | Modelo | Accuracy (val) | F1 (val) | FN (val) | AUC |
# |---|---|---|---|---|
# | DT tuneado (`threshold=0.30`) | 0.5594 | 0.6773 | 2,800 | 0.662 |
# | RF tuneado + FE (`threshold=0.45`) | 0.6206 | 0.6734 | 8,290 | 0.687 |
# | LightGBM (`threshold=0.50`) | 0.6469 | 0.6430 | 13,634 | 0.707 |
#
# RF y LightGBM mejoran el AUC respecto al DT (0.687 y 0.707 vs 0.662), pero con threshold por defecto generan muchos más FN. LightGBM es también el más eficiente computacionalmente.
#
# ### Conclusión final
# El **Decision Tree con threshold=0.30** es la propuesta principal: reduce los Falsos Negativos un 78% respecto al threshold por defecto, mantiene un F1 de 0.677. Si el objetivo fuera minimizar FN de forma aún más agresiva manteniendo AUC alto, LightGBM con threshold ajustado sería la alternativa a explorar.
#
# ### Líneas de mejora futuras
# - Ajustar el threshold de RF y LightGBM también a 0.30 para comparar FN en igualdad de condiciones
# - Feature engineering: interacciones entre variables de sistema y versiones de software
# - Validación temporal (separar train/test por fecha para evitar data leakage)
# - Actualizar dataset
